# %% [markdown]
# # Get JSON-LD from a source URL

# %%
import json
import sonormal.getjsonld

sonormal.prepareSchemaOrgLocalContexts()

url = "https://datadavev.github.io/examples/jsonld/ex01.html"

response = await sonormal.getjsonld.downloadJsonAsync(url)

# %%
response_summary = sonormal.getjsonld.responseSummary(response)
print(json.dumps(response_summary, indent=2))
# Out:
# {
#   "request": {
#     "url": "https://datadavev.github.io/examples/jsonld/ex01.html",
#     "headers": {
#       "User-Agent": "python-requests/2.25.1",
#       "Accept-Encoding": "gzip, deflate",
#       "Accept": "application/ld+json;q=1.0, application/json;q=0.9, text/html;q=0.8, application/xml+xhtml;q=0.7, */*;q=0.1",
#       "Connection": "keep-alive"
#     }
#   },
#   "responses": [
#     {
#       "url": "https://datadavev.github.io/examples/jsonld/ex01.html",
#       "status_code": 200,
#       "result": "<< body >>",
#       "elapsed": 0.063864,
#       "headers": {
#         "connection": "keep-alive",
#         "content-length": "342",
#         "server": "GitHub.com",
#         "content-type": "text/html; charset=utf-8",
#         "permissions-policy": "interest-cohort=()",
#         "last-modified": "Thu, 22 Apr 2021 21:21:27 GMT",
#         "access-control-allow-origin": "*",
#         "etag": "W/\"6081e8d7-271\"",
#         "expires": "Mon, 12 Jul 2021 15:19:18 GMT",
#         "cache-control": "max-age=600",
#         "content-encoding": "gzip",
#         "x-proxy-cache": "MISS",
#         "x-github-request-id": "517A:0AFF:12ADC12:20A02CF:60EC5B1E",
#         "accept-ranges": "bytes",
#         "date": "Mon, 12 Jul 2021 15:12:38 GMT",
#         "via": "1.1 varnish",
#         "age": "0",
#         "x-served-by": "cache-bwi5051-BWI",
#         "x-cache": "MISS",
#         "x-cache-hits": "0",
#         "x-timer": "S1626102758.200500,VS0,VE10",
#         "vary": "Accept-Encoding",
#         "x-fastly-request-id": "2361950ace193943f8fe148e1db5e8d05d574fee"
#       },
#       "content_type": "text/html; charset=utf-8",
#       "last_modified": "2021-04-22T21:21:27+0000",
#       "date": "2021-07-12T15:12:38+0000"
#     }
#   ],
#   "resources_loaded": []
# }

# %% [markdown]
# The downloaded HTML:

# %%
print(response["response"].text)
# Out:
# <!DOCTYPE html>
# <html>
#
# <head>
#     <title>Hello JSON-LD</title>
#     <link rel="stylesheet" href="../css/common.css" />
#     <script src="../js/common.js"></script>
#     <script type="application/ld+json">
#             {
#                 "@context":{
#                     "@vocab":"https://example.net/"
#                 },
#                 "@id": "http://data.example.net/example_01",
#                 "name": "This is example 01"
#             }
#         </script>
# </head>
#
# <body>
#     <p>Hello JSON-LD.</p>
#     <p><a href="https://github.com/datadavev/examples/blob/main/docs/jsonld/ex01.html">View the source.</a></p>
# </body>
#
# </html>

# %% [markdown]
# The extracted JSON-LD

# %%
print(json.dumps(response["document"], indent=2))
# Out:
# {
#   "@context": {
#     "@vocab": "https://example.net/"
#   },
#   "@id": "http://data.example.net/example_01",
#   "name": "This is example 01"
# }

# %% [markdown]
# Retrieve from a service with a few redirects

# %%
url = "https://earthref.org/MagIC/17099"
url = "https://search.dataone.org/view/https%3A%2F%2Fpasta.lternet.edu%2Fpackage%2Fmetadata%2Feml%2Fknb-lter-cap%2F686%2F1"
response = await sonormal.getjsonld.downloadJsonAsync(url)

response_summary = sonormal.getjsonld.responseSummary(response)
print(json.dumps(response_summary, indent=2))
# Out:
# No JSON-LD in plain source https://search.dataone.org/view/https%3A%2F%2Fpasta.lternet.edu%2Fpackage%2Fmetadata%2Feml%2Fknb-lter-cap%2F686%2F1
# {
#   "request": {
#     "url": "https://search.dataone.org/view/https%3A%2F%2Fpasta.lternet.edu%2Fpackage%2Fmetadata%2Feml%2Fknb-lter-cap%2F686%2F1",
#     "headers": {
#       "upgrade-insecure-requests": "1",
#       "user-agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_16_0) AppleWebKit/537.36 (KHTML, like Gecko) HeadlessChrome/71.0.3542.0 Safari/537.36",
#       "accept": "application/ld+json;q=1.0, application/json;q=0.9, text/html;q=0.8, application/xml+xhtml;q=0.7, */*;q=0.1"
#     }
#   },
#   "responses": [
#     {
#       "url": "https://search.dataone.org/view/https%3A%2F%2Fpasta.lternet.edu%2Fpackage%2Fmetadata%2Feml%2Fknb-lter-cap%2F686%2F1",
#       "status_code": 200,
#       "result": "<< body >>",
#       "elapsed": 0.272944,
#       "headers": {
#         "date": "Mon, 12 Jul 2021 15:14:27 GMT",
#         "server": "Apache/2.4.48 (Ubuntu)",
#         "last-modified": "Fri, 09 Apr 2021 20:19:29 GMT",
#         "etag": "\"287b-5bf8fe18ed61a-gzip\"",
#         "accept-ranges": "bytes",
#         "vary": "Accept-Encoding,Origin",
#         "content-encoding": "gzip",
#         "content-length": "2675",
#         "keep-alive": "timeout=5, max=100",
#         "connection": "Keep-Alive",
#         "content-type": "text/html"
#       },
#       "content_type": "text/html",
#       "last_modified": "2021-04-09T20:19:29+0000",
#       "date": "2021-07-12T15:14:27+0000"
#     }
#   ],
#   "resources_loaded": [
#     "https://search.dataone.org/view/https%3A%2F%2Fpasta.lternet.edu%2Fpackage%2Fmetadata%2Feml%2Fknb-lter-cap%2F686%2F1",
#     "https://search.dataone.org/js/themes/dataone/config.js?v=0.7387059269878897",
#     "https://search.dataone.org/loader.js?v=2.15.0",
#     "https://search.dataone.org/js/themes/dataone/config.js?v=2.15.0",
#     "https://search.dataone.org/components/require.js",
#     "https://search.dataone.org/js/app.js?v=2.15.0",
#     "https://search.dataone.org/js/views/AppView.js?v=2.15.0",
#     "https://search.dataone.org/js/models/AppModel.js?v=2.15.0",
#     "https://search.dataone.org/components/jquery-1.9.1.min.js?v=2.15.0",
#     "https://search.dataone.org/js/views/AltHeaderView.js?v=2.15.0",
#     "https://search.dataone.org/js/views/NavbarView.js?v=2.15.0",
#     "https://search.dataone.org/js/views/FooterView.js?v=2.15.0",
#     "https://search.dataone.org/js/views/SignInView.js?v=2.15.0",
#     "https://search.dataone.org/components/require-text.js?v=2.15.0",
#     "https://search.dataone.org/components/underscore-min.js?v=2.15.0",
#     "https://search.dataone.org/js/templates/alert.html?v=2.15.0",
#     "https://search.dataone.org/js/themes/dataone/templates/appHead.html?v=2.15.0",
#     "https://search.dataone.org/js/templates/jsonld.txt?v=2.15.0",
#     "https://search.dataone.org/js/themes/dataone/templates/app.html?v=2.15.0",
#     "https://search.dataone.org/js/templates/loading.html?v=2.15.0",
#     "https://search.dataone.org/js/themes/dataone/components/d1website/navbar.html?v=2.15.0",
#     "https://search.dataone.org/js/templates/altHeader.html?v=2.15.0",
#     "https://search.dataone.org/js/templates/defaultHeader.html?v=2.15.0",
#     "https://search.dataone.org/js/themes/dataone/templates/login.html?v=2.15.0",
#     "https://search.dataone.org/js/templates/loginButtons.html?v=2.15.0",
#     "https://search.dataone.org/js/templates/loginOptions.html?v=2.15.0",
#     "https://search.dataone.org/js/templates/login-ldap.html?v=2.15.0",
#     "https://search.dataone.org/js/themes/dataone/components/d1website/footer.html?v=2.15.0",
#     "https://search.dataone.org/components/bootstrap.min.js?v=2.15.0",
#     "https://search.dataone.org/components/backbone-min.js?v=2.15.0",
#     "https://search.dataone.org/js/themes/dataone/routers/router.js?v=2.15.0",
#     "https://search.dataone.org/js/collections/SolrResults.js?v=2.15.0",
#     "https://search.dataone.org/js/models/Search.js?v=2.15.0",
#     "https://search.dataone.org/js/models/Stats.js?v=2.15.0",
#     "https://search.dataone.org/js/models/Map.js?v=2.15.0",
#     "https://search.dataone.org/js/models/LookupModel.js?v=2.15.0",
#     "https://search.dataone.org/js/models/NodeModel.js?v=2.15.0",
#     "https://search.dataone.org/js/models/UserModel.js?v=2.15.0",
#     "https://search.dataone.org/js/models/DataONEObject.js?v=2.15.0",
#     "https://search.dataone.org/js/collections/DataPackage.js?v=2.15.0",
#     "https://search.dataone.org/js/routers/router.js?v=2.15.0",
#     "https://search.dataone.org/js/models/SolrHeader.js?v=2.15.0",
#     "https://search.dataone.org/js/models/SolrResult.js?v=2.15.0",
#     "https://search.dataone.org/components/async.js?v=2.15.0",
#     "https://search.dataone.org/components/jquery-ui.min.js?v=2.15.0",
#     "https://search.dataone.org/js/collections/Filters.js?v=2.15.0",
#     "https://search.dataone.org/components/es6-promise.min.js?v=2.15.0",
#     "https://search.dataone.org/components/he.js?v=2.15.0",
#     "https://search.dataone.org/js/collections/AccessPolicy.js?v=2.15.0",
#     "https://search.dataone.org/js/collections/ObjectFormats.js?v=2.15.0",
#     "https://search.dataone.org/components/md5.js?v=2.15.0",
#     "https://search.dataone.org/components/jsrsasign-4.9.0.min.js?v=2.15.0",
#     "https://search.dataone.org/components/uuid.js?v=2.15.0",
#     "https://maps.googleapis.com/maps/api/js?v=3&key=AIzaSyDuQ9r_7EeSfspKYs2SET7sv4c8FysLIk4&callback=__async_req_1__",
#     "https://search.dataone.org/js/models/filters/Filter.js?v=2.15.0",
#     "https://search.dataone.org/js/models/metadata/ScienceMetadata.js?v=2.15.0",
#     "https://search.dataone.org/js/models/metadata/eml211/EML211.js?v=2.15.0",
#     "https://search.dataone.org/js/models/filters/BooleanFilter.js?v=2.15.0",
#     "https://search.dataone.org/js/models/filters/ChoiceFilter.js?v=2.15.0",
#     "https://search.dataone.org/js/models/filters/DateFilter.js?v=2.15.0",
#     "https://search.dataone.org/js/models/filters/NumericFilter.js?v=2.15.0",
#     "https://search.dataone.org/js/models/filters/ToggleFilter.js?v=2.15.0",
#     "https://search.dataone.org/components/rdflib.min.js?v=2.15.0",
#     "https://search.dataone.org/js/models/AccessRule.js?v=2.15.0",
#     "https://search.dataone.org/components/xml2json.js?v=2.15.0",
#     "https://search.dataone.org/js/models/formats/ObjectFormat.js?v=2.15.0",
#     "https://search.dataone.org/components/jws-3.2.min.js?v=2.15.0",
#     "https://search.dataone.org/js/collections/Units.js?v=2.15.0",
#     "https://search.dataone.org/js/models/metadata/eml211/EMLGeoCoverage.js?v=2.15.0",
#     "https://search.dataone.org/js/models/metadata/eml211/EMLKeywordSet.js?v=2.15.0",
#     "https://search.dataone.org/js/models/metadata/eml211/EMLTaxonCoverage.js?v=2.15.0",
#     "https://search.dataone.org/js/models/metadata/eml211/EMLTemporalCoverage.js?v=2.15.0",
#     "https://search.dataone.org/js/models/metadata/eml211/EMLDistribution.js?v=2.15.0",
#     "https://search.dataone.org/js/models/metadata/eml211/EMLEntity.js?v=2.15.0",
#     "https://search.dataone.org/js/models/metadata/eml211/EMLDataTable.js?v=2.15.0",
#     "https://search.dataone.org/js/models/metadata/eml211/EMLOtherEntity.js?v=2.15.0",
#     "https://search.dataone.org/js/models/metadata/eml211/EMLParty.js?v=2.15.0",
#     "https://search.dataone.org/js/models/metadata/eml211/EMLProject.js?v=2.15.0",
#     "https://search.dataone.org/js/models/metadata/eml211/EMLText.js?v=2.15.0",
#     "https://search.dataone.org/js/models/metadata/eml211/EMLMethods.js?v=2.15.0",
#     "https://search.dataone.org/js/models/metadata/eml211/EMLUnit.js?v=2.15.0",
#     "https://search.dataone.org/js/models/metadata/eml211/EMLAttribute.js?v=2.15.0",
#     "https://search.dataone.org/js/models/metadata/eml211/EMLMeasurementScale.js?v=2.15.0",
#     "https://search.dataone.org/js/models/metadata/eml211/EMLNonNumericDomain.js?v=2.15.0",
#     "https://search.dataone.org/js/models/metadata/eml211/EMLNumericDomain.js?v=2.15.0",
#     "https://search.dataone.org/js/models/metadata/eml211/EMLDateTimeDomain.js?v=2.15.0",
#     "https://cn.dataone.org/cn/v2/node/",
#     "https://cn.dataone.org/portal/token",
#     "https://search.dataone.org/components/fancybox/jquery.fancybox.css?v=2.1.5",
#     "https://search.dataone.org/components/fancybox/helpers/jquery.fancybox-buttons.css?v=1.0.5",
#     "https://search.dataone.org/components/fancybox/helpers/jquery.fancybox-thumbs.css?v=1.0.7",
#     "https://search.dataone.org/css/bootstrap.min.css",
#     "https://search.dataone.org/css/font-awesome-3.2.1.min.css",
#     "https://search.dataone.org/css/jquery.sidr.light.css",
#     "https://search.dataone.org/css/metacatui-common.css?v=2.15.0",
#     "https://search.dataone.org/js/themes/dataone/css/metacatui.css?v=2.15.0",
#     "https://search.dataone.org/css/metacatui-common.responsive.css?v=2.15.0",
#     "https://search.dataone.org/js/themes/dataone/css/metacatui.responsive.css?v=2.15.0",
#     "https://search.dataone.org/components/bioportal/jquery.ncbo.tree.min.css",
#     "https://search.dataone.org/js/themes/dataone/components/d1website/css/d1website.min.css?v=2.15.0",
#     "https://search.dataone.org/js/themes/dataone/components/d1website/d1website.min.js?_=1626102868587",
#     "https://www.google-analytics.com/analytics.js",
#     "https://static.mailerlite.com/js/w/webforms.min.js?v4a60e9ef938a7fa0240ac9ba567062cb&_=1626102868588",
#     "https://search.dataone.org/img/orcid_64x64.png",
#     "https://search.dataone.org/img/Google-logo.png",
#     "https://track.mailerlite.com/webforms/o/1647596/b7u9a7?v4a60e9ef938a7fa0240ac9ba567062cb",
#     "https://search.dataone.org/js/views/MetadataView.js?v=2.15.0",
#     "https://search.dataone.org/js/themes/dataone/components/d1website/fonts/martel-v4-latin-700.woff2",
#     "https://search.dataone.org/js/themes/dataone/components/d1website/fonts/work-sans-v5-latin-regular.woff2",
#     "https://search.dataone.org/js/themes/dataone/components/d1website/fonts/work-sans-v5-latin-500.woff2",
#     "https://search.dataone.org/js/themes/dataone/components/d1website/fonts/work-sans-v5-latin-300.woff2",
#     "https://search.dataone.org/js/themes/dataone/components/d1website/fonts/work-sans-v5-latin-600.woff2",
#     "https://search.dataone.org/js/themes/dataone/components/d1website/fonts/work-sans-v5-latin-700.woff2",
#     "https://www.google-analytics.com/j/collect?v=1&_v=j91&a=1620552367&t=pageview&_s=1&dl=https%3A%2F%2Fsearch.dataone.org%2Fview%2Fhttps%253A%252F%252Fpasta.lternet.edu%252Fpackage%252Fmetadata%252Feml%252Fknb-lter-cap%252F686%252F1&ul=en-us&de=UTF-8&dt=DataONE%20Data%20Catalog&sd=24-bit&sr=1792x1120&vp=800x600&je=0&_u=IEBAAEABAAAAAC~&jid=1707682728&gjid=1096842100&cid=1579440955.1626102870&tid=UA-15017327-17&_gid=1732270193.1626102870&_r=1&_slc=1&z=349114777",
#     "https://static.mailerlite.com/js/w/ml_jQuery.inputmask.bundle.min.js?v3.3.1",
#     "https://search.dataone.org/components/clipboard.min.js?v=2.15.0",
#     "https://search.dataone.org/js/models/PackageModel.js?v=2.15.0",
#     "https://search.dataone.org/js/models/MetricsModel.js?v=2.15.0",
#     "https://search.dataone.org/js/common/Utilities.js?v=2.15.0",
#     "https://search.dataone.org/js/views/DownloadButtonView.js?v=2.15.0",
#     "https://search.dataone.org/js/views/ProvChartView.js?v=2.15.0",
#     "https://search.dataone.org/js/views/MetadataIndexView.js?v=2.15.0",
#     "https://search.dataone.org/js/views/ExpandCollapseListView.js?v=2.15.0",
#     "https://search.dataone.org/js/views/ProvStatementView.js?v=2.15.0",
#     "https://search.dataone.org/js/views/PackageTableView.js?v=2.15.0",
#     "https://search.dataone.org/js/views/CitationView.js?v=2.15.0",
#     "https://search.dataone.org/js/views/AnnotationView.js?v=2.15.0",
#     "https://search.dataone.org/js/views/MarkdownView.js?v=2.15.0",
#     "https://search.dataone.org/js/templates/metadata/metadata.html?v=2.15.0",
#     "https://search.dataone.org/js/templates/dataSource.html?v=2.15.0",
#     "https://search.dataone.org/js/templates/publishDOI.html?v=2.15.0",
#     "https://search.dataone.org/js/templates/newerVersion.html?v=2.15.0",
#     "https://search.dataone.org/js/templates/metadataControls.html?v=2.15.0",
#     "https://search.dataone.org/js/templates/metadataInfoIcons.html?v=2.15.0",
#     "https://search.dataone.org/js/templates/editMetadata.html?v=2.15.0",
#     "https://search.dataone.org/js/templates/dataDisplay.html?v=2.15.0",
#     "https://search.dataone.org/js/templates/map.html?v=2.15.0",
#     "https://search.dataone.org/js/templates/annotation.html?v=2.15.0",
#     "https://search.dataone.org/js/templates/metaTagsHighwirePress.html?v=2.15.0",
#     "https://search.dataone.org/js/views/MetricView.js?v=2.15.0",
#     "https://search.dataone.org/components/fancybox/jquery.fancybox.pack.js?v=2.15.0",
#     "https://search.dataone.org/js/templates/attribute.html?v=2.15.0",
#     "https://search.dataone.org/js/views/ProvEntitySelectView.js?v=2.15.0",
#     "https://search.dataone.org/js/templates/provStatement.html?v=2.15.0",
#     "https://search.dataone.org/js/templates/downloadContents.html?v=2.15.0",
#     "https://search.dataone.org/js/templates/bioportalAnnotationTemplate.html?v=2.15.0",
#     "https://search.dataone.org/components/showdown/showdown.min.js?v=2.15.0",
#     "https://search.dataone.org/js/templates/markdown.html?v=2.15.0",
#     "https://search.dataone.org/js/views/MetricModalView.js?v=2.15.0",
#     "https://search.dataone.org/js/templates/provEntitySelect.html?v=2.15.0",
#     "https://search.dataone.org/js/views/MetricsChartView.js?v=2.15.0",
#     "https://search.dataone.org/js/templates/metricModalTemplate.html?v=2.15.0",
#     "https://search.dataone.org/js/collections/Citations.js?v=2.15.0",
#     "https://search.dataone.org/js/views/CitationListView.js?v=2.15.0",
#     "https://search.dataone.org/components/d3.v3.min.js?v=2.15.0",
#     "https://search.dataone.org/js/models/CitationModel.js?v=2.15.0",
#     "https://search.dataone.org/cn/v2/query/solr/?q=(id:%22https\\%3A%2F%2Fpasta.lternet.edu%2Fpackage%2Fmetadata%2Feml%2Fknb-lter-cap%2F686%2F1%22%20OR%20seriesId:%22https\\%3A%2F%2Fpasta.lternet.edu%2Fpackage%2Fmetadata%2Feml%2Fknb-lter-cap%2F686%2F1%22)&fl=abstract,id,seriesId,fileName,resourceMap,formatType,formatId,obsoletedBy,isDocumentedBy,documents,title,origin,keywords,attributeName,pubDate,eastBoundCoord,westBoundCoord,northBoundCoord,southBoundCoord,beginDate,endDate,dateUploaded,archived,datasource,replicaMN,isAuthorized,isPublic,size,read_count_i,isService,serviceTitle,serviceEndpoint,serviceOutput,serviceDescription,serviceType,project,dateModified&wt=json&rows=1000&archived=archived:*",
#     "https://logproc-stage-ucsb-1.test.dataone.org/metrics?metricsRequest={%22metricsPage%22:{%22total%22:0,%22start%22:0,%22count%22:0},%22metrics%22:[%22citations%22,%22downloads%22,%22views%22],%22filterBy%22:[{%22filterType%22:%22dataset%22,%22values%22:[%22https://pasta.lternet.edu/package/metadata/eml/knb-lter-cap/686/1%22],%22interpretAs%22:%22list%22},{%22filterType%22:%22month%22,%22values%22:[%2201/01/2012%22,%2207/12/2021%22],%22interpretAs%22:%22range%22}],%22groupBy%22:[%22month%22]}",
#     "https://search.dataone.org/cn/v2/views/metacatui/https%3A%2F%2Fpasta.lternet.edu%2Fpackage%2Fmetadata%2Feml%2Fknb-lter-cap%2F686%2F1",
#     "https://search.dataone.org/cn/v2/query/solr/?fl=resourceMap,fileName,obsoletes,obsoletedBy,size,formatType,formatId,id,datasource,rightsHolder,dateUploaded,archived,title,origin,prov_instanceOfClass,isDocumentedBy,isPublic&rows=1000&q=%28resourceMap:%22doi%3A10.6073%2Fpasta%2F1e54516f04c7ef0b5c304a6f73552240%22%20OR%20id:%22doi%3A10.6073%2Fpasta%2F1e54516f04c7ef0b5c304a6f73552240%22%29&wt=json&archived=archived:*",
#     "https://raw.githubusercontent.com/DataONEorg/member-node-info/master/production/graphics/web/LTER.png",
#     "https://search.dataone.org/font/fontawesome-3.2.1/fontawesome-webfont.woff?v=3.2.1"
#   ]
# }

# %% [markdown]
# The downloaded HTML:

# %%
print(response["response"].text)
# Out:
# <!DOCTYPE html><html lang="en" data-framework="backbonejs" class=""><head>
#   <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
#   <script async="" src="//www.google-analytics.com/analytics.js"></script><script type="text/javascript" async="" src="https://maps.googleapis.com/maps/api/js?v=3&amp;key=AIzaSyDuQ9r_7EeSfspKYs2SET7sv4c8FysLIk4&amp;callback=__async_req_1__"></script><script type="text/javascript">
#     // The path to your configuration file for MetacatUI. This can be any web-accessible location.
#     var appConfigPath = "/js/themes/dataone/config.js";
#   </script>
#
#   <style>#loading-app{width:100%; height: 100%; left: 0px; top: 0px; margin-left:auto; margin-right:auto; position:absolute; background-color:#FFF;}.loading-icon{position:relative; margin-top:100px; margin-bottom:20px; margin-left: 40%; width:90px;height:90px}.loading-icon .wBall{position:absolute;width:86px;height:86px;opacity:0;-moz-transform:rotate(225deg);-moz-animation:orbit 4.4s infinite;-webkit-transform:rotate(225deg);-webkit-animation:orbit 4.4s infinite;-ms-transform:rotate(225deg);-ms-animation:orbit 4.4s infinite;-o-transform:rotate(225deg);-o-animation:orbit 4.4s infinite;transform:rotate(225deg);animation:orbit 4.4s infinite}.loading-icon .wBall .wInnerBall{position:absolute;width:11px;height:11px;background:#999;left:0;top:0;-moz-border-radius:11px;-webkit-border-radius:11px;-ms-border-radius:11px;-o-border-radius:11px;border-radius:11px}.loading-icon #wBall_1{-moz-animation-delay:.96s;-webkit-animation-delay:.96s;-ms-animation-delay:.96s;-o-animation-delay:.96s;animation-delay:.96s}.loading-icon #wBall_2{-moz-animation-delay:.19s;-webkit-animation-delay:.19s;-ms-animation-delay:.19s;-o-animation-delay:.19s;animation-delay:.19s}.loading-icon #wBall_3{-moz-animation-delay:.38s;-webkit-animation-delay:.38s;-ms-animation-delay:.38s;-o-animation-delay:.38s;animation-delay:.38s}.loading-icon #wBall_4{-moz-animation-delay:.58s;-webkit-animation-delay:.58s;-ms-animation-delay:.58s;-o-animation-delay:.58s;animation-delay:.58s}.loading-icon #wBall_5{-moz-animation-delay:.77s;-webkit-animation-delay:.77s;-ms-animation-delay:.77s;-o-animation-delay:.77s;animation-delay:.77s}@-moz-keyframes orbit {0% {opacity: 1;z-index:99;-moz-transform: rotate(180deg);-moz-animation-timing-function: ease-out;}7% {opacity: 1;-moz-transform: rotate(300deg);-moz-animation-timing-function: linear;-moz-origin:0%;}30% {opacity: 1;-moz-transform:rotate(410deg);-moz-animation-timing-function: ease-in-out;-moz-origin:7%;}39% {opacity: 1;-moz-transform: rotate(645deg);-moz-animation-timing-function: linear;-moz-origin:30%;}70% {opacity: 1;-moz-transform: rotate(770deg);-moz-animation-timing-function: ease-out;-moz-origin:39%;}	75% {opacity: 1;-moz-transform: rotate(900deg);-moz-animation-timing-function: ease-out;-moz-origin:70%;}	76% {opacity: 0;-moz-transform:rotate(900deg);}100% {opacity: 0;-moz-transform: rotate(900deg);}	}@-webkit-keyframes orbit {0% {opacity: 1;z-index:99;-webkit-transform: rotate(180deg);-webkit-animation-timing-function: ease-out;}7% {opacity: 1;-webkit-transform: rotate(300deg);-webkit-animation-timing-function: linear;-webkit-origin:0%;}30% {opacity: 1;-webkit-transform:rotate(410deg);-webkit-animation-timing-function: ease-in-out;-webkit-origin:7%;}39% {opacity: 1;-webkit-transform: rotate(645deg);-webkit-animation-timing-function: linear;-webkit-origin:30%;}70% {opacity: 1;webkit-transform: rotate(770deg);-webkit-animation-timing-function: ease-out;-webkit-origin:39%;}75% {opacity: 1;-webkit-transform: rotate(900deg);-webkit-animation-timing-function: ease-out;-webkit-origin:70%;}76% {opacity: 0;-webkit-transform:rotate(900deg);}100% {opacity: 0;-webkit-transform: rotate(900deg);}}@-ms-keyframes orbit {0% {opacity: 1;z-index:99;-ms-transform: rotate(180deg);-ms-animation-timing-function: ease-out;}7% {opacity: 1;-ms-transform: rotate(300deg);-ms-animation-timing-function: linear;-ms-origin:0%;}	30% {opacity: 1;-ms-transform:rotate(410deg);-ms-animation-timing-function: ease-in-out;-ms-origin:7%;}39% {opacity: 1;-ms-transform: rotate(645deg);-ms-animation-timing-function: linear;-ms-origin:30%;}70% {opacity: 1;-ms-transform: rotate(770deg);-ms-animation-timing-function: ease-out;-ms-origin:39%;}75% {opacity: 1;-ms-transform: rotate(900deg);-ms-animation-timing-function: ease-out;-ms-origin:70%;}76% {opacity: 0;-ms-transform:rotate(900deg);}	100% {opacity: 0;-ms-transform: rotate(900deg);}}@-o-keyframes orbit {0% {opacity: 1;z-index:99;-o-transform: rotate(180deg);-o-animation-timing-function: ease-out;}7% {opacity: 1;-o- ...
# <script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="/js/app.js?v=2.15.0" src="/js/app.js?v=2.15.0"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="views/AppView" src="/js/views/AppView.js?v=2.15.0"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="models/AppModel" src="/js/models/AppModel.js?v=2.15.0"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="jquery" src="/components/jquery-1.9.1.min.js?v=2.15.0"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="views/AltHeaderView" src="/js/views/AltHeaderView.js?v=2.15.0"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="views/NavbarView" src="/js/views/NavbarView.js?v=2.15.0"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="views/FooterView" src="/js/views/FooterView.js?v=2.15.0"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="views/SignInView" src="/js/views/SignInView.js?v=2.15.0"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="text" src="/components/require-text.js?v=2.15.0"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="underscore" src="/components/underscore-min.js?v=2.15.0"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="bootstrap" src="/components/bootstrap.min.js?v=2.15.0"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="backbone" src="/components/backbone-min.js?v=2.15.0"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="/js/themes/dataone/routers/router.js" src="/js/themes/dataone/routers/router.js?v=2.15.0"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="collections/SolrResults" src="/js/collections/SolrResults.js?v=2.15.0"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="models/Search" src="/js/models/Search.js?v=2.15.0"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="models/Stats" src="/js/models/Stats.js?v=2.15.0"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="models/Map" src="/js/models/Map.js?v=2.15.0"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="models/LookupModel" src="/js/models/LookupModel.js?v=2.15.0"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="models/NodeModel" src="/js/models/NodeModel.js?v=2.15.0"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="models/UserModel" src="/js/models/UserModel.js?v=2.15.0"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="models/DataONEObject" src="/js/models/DataONEObject.js?v=2.15.0"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="collections/DataPackage" src="/js/collections/DataPackage.js?v=2.15.0"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="/js/routers/router.js" src="/js/routers/router.js?v=2.15.0"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="models/SolrHeader" src="/js/models/SolrHeader.js?v=2.15.0">< ...
#     <meta charset="utf-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0, minimum-scale=1.0">
#     <meta name="description" content="Metacat UI">
#     <meta name="author" content="Ecoinformatics Development Team">
#
#     <!-- HTML5 shim, for IE6-8 support of HTML5 elements -->
#     <!--[if lt IE 9]>
#       <script src="/components/html5shiv.js"></script>
#     <![endif]-->
#
#     <!-- For IE <= 9 -->
#     <!--[if IE]>
#     <script type="text/javascript">
#       window.location = "https://dataone.org/unsupportedbrowser";
#     </script>
#     <![endif]-->
#     <!-- For IE > 9 -->
#     <script type="text/javascript">
#       if (window.navigator.msPointerEnabled) { window.location = "https://dataone.org/unsupportedbrowser"; }
#     </script>
#
#     <!-- Stylesheets -->
#     <link href="/components/fancybox/jquery.fancybox.css?v=2.1.5" rel="stylesheet" type="text/css">
#     <link href="/components/fancybox/helpers/jquery.fancybox-buttons.css?v=1.0.5" rel="stylesheet" type="text/css">
#     <link href="/components/fancybox/helpers/jquery.fancybox-thumbs.css?v=1.0.7" rel="stylesheet" type="text/css">
#     <link href="/css/bootstrap.min.css" type="text/css" rel="stylesheet">
#     <link href="/css/font-awesome-3.2.1.min.css" type="text/css" rel="stylesheet">
#     <link href="/css/jquery.sidr.light.css" type="text/css" rel="stylesheet">
#     <link href="/css/metacatui-common.css?v=2.15.0" type="text/css" rel="stylesheet">
#     <link href="/js/themes/dataone/css/metacatui.css?v=2.15.0" type="text/css" rel="stylesheet">
#     <link href="/css/metacatui-common.responsive.css?v=2.15.0" type="text/css" rel="stylesheet">
#     <link href="/js/themes/dataone/css/metacatui.responsive.css?v=2.15.0" type="text/css" rel="stylesheet">
#
#
#
#
#       <link href="/components/bioportal/jquery.ncbo.tree.min.css" rel="stylesheet" type="text/css">
#
#
#     <!-- Imported from the dataone website -->
#
#     <script src="/js/themes/dataone/components/d1website/d1website.min.js"></script>
#     <link href="/js/themes/dataone/components/d1website/css/d1website.min.css?v=2.15.0" type="text/css" rel="stylesheet">
#     <!-- Fav and touch icons -->
#     <link rel="apple-touch-icon" sizes="180x180" href="/js/themes/dataone/components/d1website/apple-touch-icon.png?v=2.15.0">
#     <link rel="icon" type="image/png" sizes="32x32" href="/js/themes/dataone/components/d1website/favicon-32x32.png?v=2.15.0">
#     <link rel="icon" type="image/png" sizes="16x16" href="/js/themes/dataone/components/d1website/favicon-16x16.png?v=2.15.0">
#     <link rel="manifest" href="/js/themes/dataone/components/d1website/site.webmanifest?v=2.15.0">
#     <link rel="mask-icon" href="/js/themes/dataone/components/d1website/safari-pinned-tab.svg?v=2.15.0" color="#16acc0">
#     <link rel="shortcut icon" href="/js/themes/dataone/components/d1website/favicon.ico?v=2.15.0">
#     <meta name="apple-mobile-web-app-title" content="DataONE">
#     <meta name="application-name" content="DataONE">
#     <meta name="msapplication-TileColor" content="#7aeefd">
#     <meta name="msapplication-config" content="/js/themes/dataone/components/d1website/browserconfig.xml?v=2.15.0">
#     <meta name="theme-color" content="#7aeefd">
#
#     <script>
# 	  (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 	  (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 	  m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 	  })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
# 	  ga('create', 'UA-15017327-17', 'auto');
# 	  ga('send', 'pageview');
# 	</script>
# <script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="views/MetadataView" src="/js/views/MetadataView.js?v=2.15.0"></script><script type="text/javascript" src="https://static.mailerlite.com/js/w/ml_jQuery.inputmask.bundle.min.js?v3.3.1"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="clipboard" src="/components/clipboard.min.js?v=2.15.0"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="models/PackageModel" src="/js/models/PackageModel.js?v=2.15.0"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="models/MetricsModel" src="/js/models/MetricsModel.js?v=2.15.0"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="common/Utilities" src="/js/common/Utilities.js?v=2.15.0"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="views/DownloadButtonView" src="/js/views/DownloadButtonView.js?v=2.15.0"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="views/ProvChartView" src="/js/views/ProvChartView.js?v=2.15.0"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="views/MetadataIndexView" src="/js/views/MetadataIndexView.js?v=2.15.0"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="views/ExpandCollapseListView" src="/js/views/ExpandCollapseListView.js?v=2.15.0"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="views/ProvStatementView" src="/js/views/ProvStatementView.js?v=2.15.0"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="views/PackageTableView" src="/js/views/PackageTableView.js?v=2.15.0"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="views/CitationView" src="/js/views/CitationView.js?v=2.15.0"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="views/AnnotationView" src="/js/views/AnnotationView.js?v=2.15.0"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="views/MarkdownView" src="/js/views/MarkdownView.js?v=2.15.0"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="views/MetricView" src="/js/views/MetricView.js?v=2.15.0"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="fancybox" src="/components/fancybox/jquery.fancybox.pack.js?v=2.15.0"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="views/ProvEntitySelectView" src="/js/views/ProvEntitySelectView.js?v=2.15.0"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="showdown" src="/components/showdown/showdown.min.js?v=2.15.0"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="views/MetricModalView" src="/js/views/MetricModalView.js?v=2.15.0"></script><style type="text/css">.fancybox-margin{margin-right:0px;}</style><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="MetricsChart" src="/js/views/MetricsChartView.js?v=2.15.0"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="collections/Citations" src="/js/collections/Citations.js?v=2.15.0"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="views/CitationListView" src="/js/views/CitationLis ...
# <meta name="citation_title" content="Urban Ecological Infrastructure (UEI) in the greater Phoenix, Arizona metropolitan area and surrounding Sonoran desert region (2010-2017)">
#
# <meta name="citation_author" content="Jeffrey Brown">
#
# <meta name="citation_author" content="Kelli Larson">
#
# <meta name="citation_author" content="Susannah Lerman">
#
# <meta name="citation_author" content="Dan Childers">
#
# <meta name="citation_author" content="Riley Andrade">
#
# <meta name="citation_author" content="Heather Bateman">
#
# <meta name="citation_author" content="Sharon Hall">
#
# <meta name="citation_author" content="Paige Warren">
#
# <meta name="citation_author" content="Abigail York">
#
# <meta name="citation_publisher" content="LTER Network Member Node">
# <meta name="citation_date" content="2021"></head>
# <body id="metacatui-app">
#   <div id="loading-app">
#     <div class="loading-icon"><div class="wBall" id="wBall_1"><div class="wInnerBall"></div></div><div class="wBall" id="wBall_2"><div class="wInnerBall"></div></div><div class="wBall" id="wBall_3"><div class="wInnerBall"></div></div><div class="wBall" id="wBall_4"><div class="wInnerBall"></div></div><div class="wBall" id="wBall_5"><div class="wInnerBall"></div></div></div>
#     <span>Loading...</span>
#   </div>
#   <script type="text/javascript">
#     // Load Polyfills if required. This file is loaded before even the config file loads,
#     // since even common functions are missing, such as console.log and Object.assign
#
#     // Check for at least one required polyfill.
#     // These checks are identical to those used at the start of each polyfill.
#     if(
#       !window.console ||
#       typeof String.prototype.trim !== 'function'       ||
#       !String.prototype.startsWith                      ||
#       !String.prototype.endsWith                        ||
#       !Array.isArray                                    ||
#       !Array.prototype.map                              ||
#       !Array.prototype.forEach                          ||
#       !Object.keys                                      ||
#       !Array.prototype.indexOf                          ||
#       (window.NodeList && !NodeList.prototype.forEach)  ||
#       typeof Object.assign != 'function'                ||
#       !Array.prototype.includes                         ||
#       !Math.log2                                        ||
#       (!(new Date('2011-06-02T09:34:29+02:00')) || +(new Date('2011-06-02T09:34:29+02:00')) !== 1307000069000)
#     ){
#       // use document.write to load the file synchronously
#       document.write('<script src="/js/polyfill.js"><\/script>');
#     }
#   </script>
#   <script type="text/javascript">
#
#     //Create the MetacatUI object
#     var MetacatUI = {};
#     MetacatUI.metacatUIVersion = "2.15.0";
#
#     //Catch errors when the config or loader file fails to load.
#     // These are mainly helpful for developers/operators installing MetacatUI
#     MetacatUI.onStartConfigError = function(){
#       var message = "The config file or loader.js file failed to load. Check the appConfigPath in index.html and the 'root' attribute in AppConfig.";
#       document.getElementById("metacatui-app").innerHTML = message;
#       console.error(message);
#     }
#     MetacatUI.onStartLoaderError = function(){
#       //Check for one of the functions created in the loader.js file. If it doesn't exist, then the script wasn't retrieved.
#       // (the 'onerror' event isn't triggered if there is a FallbackResource set on the web server)
#       if( typeof MetacatUI.initApp == "undefined" ){
#         var message = "The loader.js file failed to load. The MetacatUI `root` setting is probably incorrect. Set a `root` path for MetacatUI in the AppConfig.";
#         document.getElementById("metacatui-app").innerHTML = message;
#         console.error(message);
#       }
#     }
#
#     //This function gets the loader.js file
#     MetacatUI.onStartGetLoader = function(){
#
#       //When the config file is loaded, start the app by getting the loader.js script
#       var script = document.createElement("script");
#
#       //Construct the URL for the loader.js file
#       var loaderPath = (MetacatUI.AppConfig && MetacatUI.AppConfig.root)? MetacatUI.AppConfig.root : "/metacatui";
#       if( loaderPath.charAt(loaderPath.length-1) == "/" ){
#         loaderPath = loaderPath.substring(0, loaderPath.length-1);
#       }
#       loaderPath = loaderPath + "/loader.js?v=" + ((MetacatUI.AppConfig && MetacatUI.AppConfig.cachebuster)? MetacatUI.AppConfig.cachebuster : MetacatUI.metacatUIVersion);
#       script.src = loaderPath;
#       script.onerror = MetacatUI.onStartLoaderError;
#       script.onload = MetacatUI.onStartLoaderError;
#
#       //Add the loader.js script tag to the page, which will load and execute the script
#       document.getElementsByTagName("body")[0].appendChild(script);
#     }
#
#     //If there is an application configuration file, get it first
#     if( appConfigPath ){
#       try{
#         //Load the configuration file
#         var script = document.createElement("script");
#         script.src = appConfigPath + "?v=" + Math.random();
#         script.onload = MetacatUI.onStartGetLoader;
#         script.onerror = MetacatUI.onStartConfigError;
#         document.getElementsByTagName("body")[0].appendChild(script);
#       }
#       catch(e){
#         MetacatUI.onStartConfigError();
#       }
#     }
#     //Otherwise, just load the app now without custom configurations
#     else{
#       MetacatUI.onStartGetLoader();
#     }
#   </script><script src="/js/themes/dataone/config.js?v=0.7387059269878897"></script>
#
#
#
# <script src="/loader.js?v=2.15.0"></script><script type="text/javascript" src="/js/themes/dataone/config.js?v=2.15.0"></script><script data-main="/js/app.js?v=2.15.0" src="/components/require.js"></script><!-- Placeholders for the application content -->
# <nav id="Navbar" class="auto-height-member"><header class="d1_nav" id="nav">
#   <nav class="d1_nav__inner">
#
#
#     <a class="d1_nav__button d1_nav__button--logo" href="https://dataone.org"><span class="d1_nav__button-icon">
# <svg viewBox="0 0 490 109" width="143" height="32" preserveAspectRatio="xMinYMin slice" class="d1_logo d1_logo--global-nav">
#   <title>DataONE</title>
#
#   <g>
#     <path class="d1_logo__data" d="M85.014 46.38c13.316-7.251 54.107-14.185 53.727 22.269.154 9.03-.554 30.534.927 38.311h-18.173l-1.195-6.494h-.398c-4.529 5.433-11.525 8.291-19.974 7.917-25.49-.666-32.806-45.62 18.516-44.637.875-13.376-21.072-9.914-29.716-4.374zm104.66 0c13.316-7.251 54.107-14.185 53.724 22.269l.007.447c.127 9.273-.535 30.213.922 37.864h-18.172l-1.195-6.494h-.398c-4.53 5.433-11.526 8.291-19.974 7.917-25.49-.666-32.806-45.62 18.516-44.637.875-13.376-21.072-9.914-29.716-4.374zm-19.55-22.932v18.536h14.398v14.827h-14.398v22.093c.021 9.183.757 14.576 13.872 12.196l.132 15.224c-39.97 9.183-33.242-19.858-33.686-49.513h-8.586V41.984h8.586V27.95l19.682-4.501zM0 18.453c17.694-2.424 48.676-4.789 63.941 7.697 13.26 9.387 19.006 29.78 12.512 51.35C66.466 108.266 32.333 109.943 0 106.31zm119.108 57.882c-22.189-1.631-23.675 16.838-11.273 17.888 6.53.198 11.583-5.024 11.273-10.86zm104.66 0c-22.19-1.631-23.675 16.838-11.273 17.888 6.53.198 11.583-5.024 11.273-10.86zM57.486 63.64C59.1 37.956 41.79 29.163 20.296 32.918v58.527c1.724.4 4.512.4 7.031.4 17.395.056 29.02-8.833 30.16-28.204z"></path>
#
#     <path class="d1_logo__globe" d="M300.057 0l.804.008c33.62-.245 58.535 30.538 52.255 64.726-4.254 24.254-26.264 44.089-52.255 43.593-32.562.305-57.253-29.14-52.408-62.351C251.635 21.152 273.134.37 299.256.005l.801-.005zM269.33 21.06c-24.017 24.619-13.954 70.073 21.55 78.605 15.425 3.323 31.051-.743 41.869-12.389C356.365 62.86 346.706 17.57 311.812 8.77c-15.567-3.534-31.529.61-42.482 12.29zm32.627-9.646c.104.382.57.505.74.481.827-.114 1.55.352 2.36.318.564-.023 1.1.198 1.56.601.368.326.327.73.23 1.058-.093.32-.457.403-.847.419-.522.02-.977-.219-1.434-.336-.574-.146-1.172-.292-1.749-.435-.564-.14-1.193-.031-1.78-.031-.203-.284.382-.438.057-.758-.244-.24-.561-.419-.777-.255-.298.224-.756.198-.922.607.106.294.585.375.478.83-.346.19-.756.149-1.104.081-2.056-.398-2.3-.357-3.984.518-.398.206-.84.432-.816.83.031.506.644.639 1.032.717 1.19.242 2.318.723 3.59.82 0 .346-.02.643.006.935.036.395.291.598.65.611.366.016.62-.218.618-.5-.01-.684.26-1.067.886-1.34.497-.216.489-.386.291-1.029-.314-1.02.055-1.53 1.126-1.546.301-.006.683-.118.888.023.385.266.842.25 1.235.48 1.096.642 1.114.621 2.406.314.182-.044.294-.013.45.086.613.385 1.26.721 1.865 1.114.712.464 1.437.875 2.264 1.107.384.107.764.297 1.031.633.445.557 1.136.895 1.388 1.63.057.164.265.273.496.338.762.214 1.362.677 1.918 1.383-.598.265-1.07.127-1.52.153-.473.029-.951.04-1.424-.005-.359-.034-.608-.24-.598-.661.01-.43.003-.862.003-1.287-.291-.187-.551-.223-.811.042-.21.216-.489.089-.733.094-.733.018-1.468-.018-2.2.013-.62.026-1.225.14-1.685.63.19.27.473.151.694.13.512-.047.9.091 1.227.508.501.638 1.18.896 1.995.81.297-.032.595-.006.923-.006.083.347.203.706-.021.977-.2.242-.512.505-.795.534-.478.049-.824.33-1.237.47-.395.136-.86.35-1.068-.356-.101-.341-.504-.445-.86-.278-.58.273-1.073.703-1.767.76-.223.018-.445.351-.403.718.029.243.135.56-.07.735-.203.171-.512.328-.762.31-.374-.03-.553.419-.93.286-.14-.05-.278.044-.317.153-.205.602-.728.98-1.055 1.503-.385.617-.538 1.21-.473 1.885.068.685-.182 1.132-.816 1.39-1.07.437-1.968 1.146-2.842 1.865l-.58.479c-1.008.825-1.234 1.054-.504 2.645.397.87.665 1.755.605 2.742-.044.708-.431 1.158-.904 1.57-.133.114-.44.132-.587-.03-.154-.166.194-.21.179-.371-.018-.203.093-.45-.133-.591-.306-.196-.392-.529-.543-.818-.296-.573-.686-1.067-.66-1.82.026-.698-.722-1.093-1.426-1.286-.832-.227-1.653-.219-2.49-.237-.348-.008-.629.036-.917.312-.351.339-.816.503-1.351.48-.905-.04-1.814.025-2.719-.024-.532-.029-.966.143-1.398.388-.641.367-1.296.721-1.798 1.284-.273.307-.517.645-.543 1.07-.05.864-.34 1.695-.582 2.491-.247.82-.174 1.591-.18 2.378-.004.908 1.399 2.627 2.225 2.77.704.12 1.409-.05 1.988-.484.377-.282.77-.612.998-1.01.642-1.115 1.627-1.399 2.801-1.35.302.014.603.003.92.003.294.633.06 1.203-.223 1.76-.31.607-.679 1.19-.939 1.818-.08.192-.241.325-.285.53-.273 1.258.02 1.62 1.35 1.597.326-.005.659.104.989-.112.706-.464 1.208.19 1.8.372.603.188.707.779 1.032 1.188.107.132-.125.302-.156.437-.218.95-.777 1.833-.61 2.867.067.411-.175.882.15 1.231.507.544.985 1.133 1.788 1.304.64.139.868.17 1.328-.038.792-.36 1.723-.323 2.362.09.66.428 1.517.167 1.957-.491.158-.24.293-.521.395-.75.153-.344.33-.492.647-.651 1.11-.555 2.32-.86 3.41-1.482.326-.187.96-.408 1.262-.276.61.271 1.387.295 1.811.95.416.646 1.149.8 1.79.98.663.184 1.401.278 2.085-.102.132-.075.327-.057.49-.057.822-.005 1.643-.044 2.459.013.556.039 1.037.2 1.393.797a9.396 9.396 0 002.812 2.989c.63.43 1.22.609 1.954.624 1.572.034 2.954.524 4.09 1.714.475.497.437 1.244 1.063 1.663.543.362.971.893 1.2 1.563.205.6.772.867 1.323 1 .566.135 1.07.398 1.517.707.57.396 1.162.688 1.822.592 1.19-.172 2.097.354 2.934 1.054.267.224.501.279.831.258.452 1.812-.127 3.424-1.06 4.908-.883 1.403-1.634 2.87-2.175 4.42-.387 1.113-.938 2.13-1.502 3.138-.252.453-.527.914-.777 1.372-.694 1.276-1.933 1.841-3.077 2.552-1 .62-1.99 1.257-2.954 1.93-.772.538-1.226 1.39-1.785 2.119-.411.536-.79 1.041-1.388 1.377-.543.305-.962.792-1.44 1.182-.995.813-2.079 1.409-3.23 1.932-.29.133-.61.284-.816.518-1.062 1.205-2.487 1.775-3.905 2.333 ...
#
#     <path class="d1_logo__ne" d="M487.956 1.568v6.788h-43.53v42.17h42.398v6.867h-42.398v42.773h44.593v6.79h-51.782V1.569h50.719zm-124.524 0l61.682 92.105V1.568h6.288v105.389h-5.175l-61.836-92.112v92.112h-6.287V1.567h5.328z"></path>
#   </g>
# </svg>
# </span>
#       <span class="d1_nav__button-text">Home</span>
#     </a>
#
#
#     <button class="d1_nav__button d1_nav__button--menu-toggle" id="global-menu-toggle" aria-label="Open primary menu" aria-expanded="false" aria-controls="global-menu">
#       <span class="d1_nav__button-icon">
#
#
#
#
#
#
#
# <svg viewBox="0 0 24 24" class="d1_icon d1_icon--col-inherit d1_icon--str-thicker"><line x1="3" y1="12" x2="21" y2="12"></line>
# <line x1="3" y1="6" x2="21" y2="6"></line>
# <line x1="3" y1="18" x2="21" y2="18"></line></svg>
# </span>
#       <span class="d1_nav__button-text">Menu</span>
#     </button>
#
#
#     <a class="d1_nav__button d1_nav__button--mobile-find-data" href="https://search.dataone.org/data">
#       <span class="d1_nav__button-icon">
#
#
#
#
#
#
#
# <svg viewBox="0 0 24 24" class="d1_icon d1_icon--col-inherit d1_icon--str-thicker"><circle cx="11" cy="11" r="8"></circle>
# <line x1="21" y1="21" x2="16.65" y2="16.65"></line></svg>
# </span>
#       <span class="d1_nav__button-text">Find Data</span>
#     </a>
#
#
#     <div id="global-menu" aria-hidden="true" class="d1_nav__menu">
#       <ul class="d1_nav__primary-items">
#
#
#
#
#
#
# <li class="d1_menu-item d1_menu-item--no-dropdown d1_menu-item--find-data">
#
#
#
#     <a class="d1_menu-item__top-item" href="/data" title=""><span class="d1_menu-item__icon">
#
#
#
#
#
#
#
# <svg viewBox="0 0 24 24" class="d1_icon d1_icon--sz-small d1_icon--col-inherit"><circle cx="11" cy="11" r="8"></circle>
# <line x1="21" y1="21" x2="16.65" y2="16.65"></line></svg>
# </span><span class="d1_menu-item__top-item-name">Find Data</span></a>
#
#     </li>
#
#
#
#
#
#
#
# <li class="d1_menu-item d1_menu-item--dropdown d1_menu-item--services">
#
#
#
#     <button class="d1_menu-item__top-item" aria-haspopup="true" aria-expanded="false" aria-controls="services__sub-menu"><span class="d1_menu-item__top-item-name">Services</span><span class="d1_menu-item__dropdown-icon">
#
#
#
#
#
#
#
# <svg viewBox="0 0 24 24" class="d1_icon d1_icon--sz-tiny d1_icon--col-inherit d1_icon--str-thicker">
# <polyline points="6 9 12 15 18 9"></polyline></svg>
# </span></button>
#
#
#
#     <ul class="d1_menu-item__sub-menu" aria-hidden="true" id="services__sub-menu">
#
#
#
#
#
#
#           <li class="d1_menu-item__sub-item d1_menu-item__sub-item--has-icon d1_menu-item__sub-item--has-description theme--dataone-plus">
#             <a class="d1_menu-item__sub-link" href="https://dataone.org/plus/" title="DataONE Plus" id="dataone-plus__sub-link"><span class="d1_menu-item__sub-item-icon">
#
#
#
#
#
#
#
# <svg viewBox="0 0 24 24" class="d1_icon d1_icon--sz-small d1_icon--col-inherit d1_icon--fill-icon"><path stroke="null" d="M9.71 3.35c0 .01.05.05.09.06a1 1 0 00.2.05l.1.01c.12.01.3.04.38.07.08.02.17.07.18.1a.27.27 0 01.03.15c0 .04-.06.08-.12.08l-.1-.01a2.01 2.01 0 01-.07-.01l-.38-.09a2.07 2.07 0 00-.18-.03l-.17.01a.16.16 0 01-.09 0V3.7l.03-.06.01-.07c0-.01-.06-.03-.1-.03a.42.42 0 00-.16.04l-.09.07c0 .02 0 .04.03.05l.03.03c.03.02.07.04.07.06 0 .02-.04.03-.1.02L9 3.8a.9.9 0 00-.27 0l-.15.06-.08.03a1.24 1.24 0 00-.2.1c-.04.03-.07.07-.07.1s.08.09.18.12l.24.08.1.03.28.05c.05.01.1.04.1.06l-.04.13v.04c.04.04.1.07.14.08.04.02.1-.01.11-.06a.55.55 0 00.04-.16c0-.03.04-.06.08-.09l.05-.02c.07-.03.13-.07.13-.1a.21.21 0 00-.05-.1.19.19 0 01-.02-.15.35.35 0 01.05-.12c.02-.02.11-.03.2-.03l.29.05.14.06.04.04c.02.03.1.06.15.07a.32.32 0 00.11-.01l.04-.02.07-.05c.01 0 .04 0 .07.02l.25.16.22.13.08.04.2.09c.08.03.2.11.28.17.05.04.1.1.12.14l.04.06c.01.04.07.1.13.12.06.02.18.08.25.13.08.06.11.11.07.13a.67.67 0 01-.22.03l-.28-.02c-.07 0-.13-.04-.13-.08v-.05l.02-.14v-.13c-.02-.01-.07 0-.11.03a.47.47 0 01-.2.04h-.08l-.39.01a.6.6 0 00-.26.1c-.05.04-.03.06.04.05a1 1 0 01.2-.01.17.17 0 01.08.03l.02.02.05.08c.02.02.07.06.12.08.03.01.09.03.15.03h.1c.1 0 .17.02.17.06a.25.25 0 01-.05.14.46.46 0 01-.18.1 1.44 1.44 0 00-.2.08c-.05.02-.1.03-.12 0a.13.13 0 01-.04-.09c0-.03-.04-.05-.09-.05a.53.53 0 00-.12.03l-.26.12c-.05.01-.1.06-.1.1a.3.3 0 000 .08v.03l-.01.07-.03.01-.19.06c-.1.02-.2.06-.2.1l-.04.06-.07.1a1.13 1.13 0 00-.14.23.49.49 0 00-.01.27c.01.06-.03.13-.1.18l-.06.02a1.18 1.18 0 00-.25.13l-.24.19-.1.07a.61.61 0 00-.2.23.39.39 0 000 .2l.12.27.03.1c.03.1.03.23.01.31a.36.36 0 01-.13.21.4.4 0 01-.1.05h-.03l.01-.06a.09.09 0 00.02-.1l-.14-.23a.62.62 0 01-.1-.27.39.39 0 00-.05-.19.24.24 0 00-.17-.1l-.39-.04c-.15-.01-.3.02-.32.07-.03.05-.13.1-.22.1a1.67 1.67 0 01-.35-.04c-.1-.02-.32.03-.49.12-.16.08-.32.23-.35.33l-.14.5c-.05.17-.06.42-.03.55.04.14.15.3.25.38.1.07.23.11.3.1l.17-.06a.37.37 0 00.14-.1l.18-.22a.59.59 0 01.28-.16.8.8 0 01.31 0c.06 0 .07.11.02.24l-.04.08a2.94 2.94 0 00-.22.52c-.04.13.03.23.15.23l.2-.01.11-.02a.7.7 0 00.04 0c.07-.03.22.02.33.1.1.07.15.2.1.3a1.68 1.68 0 00-.1.4c-.02.14 0 .3.05.37.04.06.16.16.26.2.1.05.23.05.29.02a.47.47 0 01.22-.07c.06 0 .17.03.23.07a.32.32 0 00.24.04.28.28 0 00.15-.14l.02-.07c.02-.08.13-.18.23-.22.1-.03.3-.1.42-.17a1.13 1.13 0 01.38-.1c.06 0 .15.03.23.07l.06.06c.08.07.2.16.28.19a.8.8 0 00.32.04l.3-.03h.49a.3.3 0 01.17.1l.04.07c.05.08.17.23.28.34.11.11.29.23.39.27.07.03.16.05.23.05h.17c.1.01.24.06.36.12.14.08.27.22.3.3 0 .08.05.15.1.2l.05.02a.33.33 0 01.15.15l.02.08a.36.36 0 00.19.2l.06.02a1.02 1.02 0 01.33.16.5.5 0 00.35.08.57.57 0 01.39.11c.1.09.21.15.25.15.05 0 .08.11.08.25 0 .11-.1.34-.21.56l-.07.13c-.13.2-.26.48-.34.7l-.06.16-.01.06-.23.4-.19.33-.04.07c-.07.1-.28.26-.51.4l-.14.08c-.28.15-.55.36-.6.47a1.61 1.61 0 01-.3.37l-.16.13a7.43 7.43 0 01-.2.15l-.12.1a4.23 4.23 0 01-.4.24l-.08.04a.94.94 0 00-.2.12l-.04.04a.93.93 0 01-.24.19l-.33.15-.12.05a4.59 4.59 0 00-.46.19 1.4 1.4 0 00-.26.17l-.05.05a1.11 1.11 0 01-.33.22c-.13.05-.34.1-.48.09a.73.73 0 01-.36-.09c-.05-.04-.06-.12-.01-.16a.67.67 0 00.12-.18l.04-.08c.02-.07.06-.15.1-.2l.04-.09a1.95 1.95 0 00.26-.5l.02-.05a1.26 1.26 0 01.07-.2l.03-.07a3.02 3.02 0 00.15-.4l.1-.4a1.09 1.09 0 00.01-.39c-.02-.11-.1-.23-.2-.27a2.9 2.9 0 01-.36-.17 1.59 1.59 0 01-.32-.26l-.19-.2-.06-.1-.3-.49-.19-.3-.15-.22a3.55 3.55 0 01-.18-.25.66.66 0 01-.1-.22l.02-.19v-.08l.06-.29.03-.15a.77.77 0 01.18-.34l.16-.16.26-.28c.05-.04.07-.12.06-.16l-.02-.1a1.44 1.44 0 010-.06l-.01-.33a.2.2 0 00-.05-.1l-.05-.04a.28.28 0 01-.1-.17.23.23 0 00-.06-.13c-.02-.03-.07-.03-.09-.01l-.07.05-.04.03a.12.12 0 00-.05.13c.01.05-.05.07-.14.06-.1 0-.18-.05-.19-.08-.01-.03-.06-.07-.1-.08l-.18-.06a.21.21 0 01-.09-.05l-.02-.03c0-.03-.07-.08-.16-.14l-.06-.04c-.1-.05-.16-.1-.16-.15v-.02c.04-.04.02-.12-.05-.2a1.92 1.92 0 00-.3-.24l-.35-.2a.87.87 0 00-.22-.08l-.05-.01a.2.2 0 01-.15-.08l-.12-.16-.1-.1a.32.32 0 00-.19-.1.33.33 0 00-. ...
# </svg>
# </span><p class="d1_menu-item__sub-item-name">DataONE Plus</p><p class="d1_menu-item__sub-item-description">Portals, custom search, metrics &amp; more</p></a>
#           </li>
#
#
#
#
#
#
#           <li class="d1_menu-item__sub-item d1_menu-item__sub-item--has-icon d1_menu-item__sub-item--has-description theme--hosted-repository">
#             <a class="d1_menu-item__sub-link" href="https://dataone.org/hosted-repo/" title="Hosted Repository" id="hosted-repository__sub-link"><span class="d1_menu-item__sub-item-icon">
#
#
#
#
#
#
#
# <svg viewBox="0 0 24 24" class="d1_icon d1_icon--sz-small d1_icon--col-inherit"><ellipse cx="12" cy="5" rx="9" ry="3"></ellipse>
# <path d="M21 12c0 1.66-4 3-9 3s-9-1.34-9-3"></path>
# <path d="M3 5v14c0 1.66 4 3 9 3s9-1.34 9-3V5"></path></svg>
# </span><p class="d1_menu-item__sub-item-name">Hosted Repository</p><p class="d1_menu-item__sub-item-description">A dedicated repository for your data</p></a>
#           </li>
#
#
#
#
#
#
#           <li class="d1_menu-item__sub-item d1_menu-item__sub-item--bottom">
#             <a class="d1_menu-item__sub-link" href="https://dataone.org/services/" title="Services" id="all-services-features__sub-link"><p class="d1_menu-item__sub-item-name">All services &amp; features
#
#
#
#
#
#
#
# <svg viewBox="0 0 24 24" class="d1_icon d1_icon--sz-small d1_icon--col-inherit"><line x1="5" y1="12" x2="19" y2="12"></line>
# <polyline points="12 5 19 12 12 19"></polyline></svg>
# </p></a>
#           </li></ul>
#     <div class="d1_menu-item__sub-menu-arrow"></div></li>
#
#
#
#
#
#
#
# <li class="d1_menu-item d1_menu-item--dropdown d1_menu-item--community">
#
#
#
#     <button class="d1_menu-item__top-item" aria-haspopup="true" aria-expanded="false" aria-controls="community__sub-menu"><span class="d1_menu-item__top-item-name">Community</span><span class="d1_menu-item__dropdown-icon">
#
#
#
#
#
#
#
# <svg viewBox="0 0 24 24" class="d1_icon d1_icon--sz-tiny d1_icon--col-inherit d1_icon--str-thicker">
# <polyline points="6 9 12 15 18 9"></polyline></svg>
# </span></button>
#
#
#
#     <ul class="d1_menu-item__sub-menu" aria-hidden="true" id="community__sub-menu">
#
#
#
#
#
#
#           <li class="d1_menu-item__sub-item d1_menu-item__sub-item--has-icon d1_menu-item__sub-item--has-description">
#             <a class="d1_menu-item__sub-link" href="https://dataone.org/network/" title="Member repositories" id="member-repositories__sub-link"><span class="d1_menu-item__sub-item-icon">
#
#
#
#
#
#
#
# <svg viewBox="0 0 24 24" class="d1_icon d1_icon--sz-small d1_icon--col-inherit"><rect x="2" y="2" width="20" height="8" rx="2" ry="2"></rect>
# <rect x="2" y="14" width="20" height="8" rx="2" ry="2"></rect>
# <line x1="6" y1="6" x2="6.01" y2="6"></line>
# <line x1="6" y1="18" x2="6.01" y2="18"></line></svg>
# </span><p class="d1_menu-item__sub-item-name">Member repositories</p><p class="d1_menu-item__sub-item-description">Our federated network of data repos</p></a>
#           </li>
#
#
#
#
#
#
#           <li class="d1_menu-item__sub-item d1_menu-item__sub-item--has-icon d1_menu-item__sub-item--has-description">
#             <a class="d1_menu-item__sub-link" href="https://dataone.org/community/" title="DataONE Community" id="the-dataone-community__sub-link"><span class="d1_menu-item__sub-item-icon">
#
#
#
#
#
#
#
# <svg viewBox="0 0 24 24" class="d1_icon d1_icon--sz-small d1_icon--col-inherit"><path d="M17 21v-2a4 4 0 0 0-4-4H5a4 4 0 0 0-4 4v2"></path>
# <circle cx="9" cy="7" r="4"></circle>
# <path d="M23 21v-2a4 4 0 0 0-3-3.87"></path>
# <path d="M16 3.13a4 4 0 0 1 0 7.75"></path></svg>
# </span><p class="d1_menu-item__sub-item-name">The DataONE Community</p><p class="d1_menu-item__sub-item-description">Help shape the future of DataONE</p></a>
#           </li>
#
#
#
#
#
#
#           <li class="d1_menu-item__sub-item d1_menu-item__sub-item--bottom">
#             <a class="d1_menu-item__sub-link" href="https://dataone.org/participate/" title="Participate" id="how-to-participate__sub-link"><p class="d1_menu-item__sub-item-name">How to participate
#
#
#
#
#
#
#
# <svg viewBox="0 0 24 24" class="d1_icon d1_icon--sz-small d1_icon--col-inherit"><line x1="5" y1="12" x2="19" y2="12"></line>
# <polyline points="12 5 19 12 12 19"></polyline></svg>
# </p></a>
#           </li></ul>
#     <div class="d1_menu-item__sub-menu-arrow"></div></li>
#
#
#
#
#
#
#
# <li class="d1_menu-item d1_menu-item--dropdown d1_menu-item--learning">
#
#
#
#     <button class="d1_menu-item__top-item" aria-haspopup="true" aria-expanded="false" aria-controls="learning__sub-menu"><span class="d1_menu-item__top-item-name">Learning</span><span class="d1_menu-item__dropdown-icon">
#
#
#
#
#
#
#
# <svg viewBox="0 0 24 24" class="d1_icon d1_icon--sz-tiny d1_icon--col-inherit d1_icon--str-thicker">
# <polyline points="6 9 12 15 18 9"></polyline></svg>
# </span></button>
#
#
#
#     <ul class="d1_menu-item__sub-menu" aria-hidden="true" id="learning__sub-menu">
#
#
#
#
#
#
#           <li class="d1_menu-item__sub-item d1_menu-item__sub-item--has-icon">
#             <a class="d1_menu-item__sub-link" href="https://dataone.org/webinars/" title="The DataONE Webinar Series" id="webinars__sub-link"><span class="d1_menu-item__sub-item-icon">
#
#
#
#
#
#
#
# <svg viewBox="0 0 24 24" class="d1_icon d1_icon--sz-small d1_icon--col-inherit"><path d="M3 18v-6a9 9 0 0 1 18 0v6"></path>
# <path d="M21 19a2 2 0 0 1-2 2h-1a2 2 0 0 1-2-2v-3a2 2 0 0 1 2-2h3zM3 19a2 2 0 0 0 2 2h1a2 2 0 0 0 2-2v-3a2 2 0 0 0-2-2H3z"></path></svg>
# </span><p class="d1_menu-item__sub-item-name">Webinars</p></a>
#           </li>
#
#
#
#
#
#
#           <li class="d1_menu-item__sub-item d1_menu-item__sub-item--has-icon">
#             <a class="d1_menu-item__sub-link" href="https://dataone.org/training/" title="Training" id="training__sub-link"><span class="d1_menu-item__sub-item-icon">
#
#
#
#
#
#
#
# <svg viewBox="0 0 24 24" class="d1_icon d1_icon--sz-small d1_icon--col-inherit"><rect x="2" y="7" width="20" height="14" rx="2" ry="2"></rect>
# <path d="M16 21V5a2 2 0 0 0-2-2h-4a2 2 0 0 0-2 2v16"></path></svg>
# </span><p class="d1_menu-item__sub-item-name">Training</p></a>
#           </li>
#
#
#
#
#
#
#           <li class="d1_menu-item__sub-item d1_menu-item__sub-item--has-icon">
#             <a class="d1_menu-item__sub-link" href="https://dataoneorg.github.io/Education/" title="Skillbuilding Hub" id="skillbuilding__sub-link"><span class="d1_menu-item__sub-item-icon">
#
#
#
#
#
#
#
# <svg viewBox="0 0 24 24" class="d1_icon d1_icon--sz-small d1_icon--col-inherit"><circle cx="12" cy="8" r="7"></circle>
# <polyline points="8.21 13.89 7 23 12 20 17 23 15.79 13.88"></polyline></svg>
# </span><p class="d1_menu-item__sub-item-name">Skillbuilding</p></a>
#           </li>
#
#
#
#
#
#
#           <li class="d1_menu-item__sub-item d1_menu-item__sub-item--has-icon">
#             <a class="d1_menu-item__sub-link" href="https://dataone.org/portals-tutorial/" title="Portals How-To" id="portals-how-to__sub-link"><span class="d1_menu-item__sub-item-icon">
#
#
#
#
#
#
#
# <svg viewBox="0 0 24 24" class="d1_icon d1_icon--sz-small d1_icon--col-inherit">
# <polygon points="12 2 15.09 8.26 22 9.27 17 14.14 18.18 21.02 12 17.77 5.82 21.02 7 14.14 2 9.27 8.91 8.26 12 2"></polygon></svg>
# </span><p class="d1_menu-item__sub-item-name">Portals How-To</p></a>
#           </li></ul>
#     <div class="d1_menu-item__sub-menu-arrow"></div></li>
#
#
#
#
#
#
#
# <li class="d1_menu-item d1_menu-item--dropdown d1_menu-item--about">
#
#
#
#     <button class="d1_menu-item__top-item" aria-haspopup="true" aria-expanded="false" aria-controls="about__sub-menu"><span class="d1_menu-item__top-item-name">About</span><span class="d1_menu-item__dropdown-icon">
#
#
#
#
#
#
#
# <svg viewBox="0 0 24 24" class="d1_icon d1_icon--sz-tiny d1_icon--col-inherit d1_icon--str-thicker">
# <polyline points="6 9 12 15 18 9"></polyline></svg>
# </span></button>
#
#
#
#     <ul class="d1_menu-item__sub-menu" aria-hidden="true" id="about__sub-menu">
#
#
#
#
#
#
#           <li class="d1_menu-item__sub-item d1_menu-item__sub-item--has-icon">
#             <a class="d1_menu-item__sub-link" href="https://dataone.org/about/" title="About DataONE" id="about-dataone__sub-link"><span class="d1_menu-item__sub-item-icon">
#
#
#
#
#
#
#
# <svg viewBox="0 0 24 24" class="d1_icon d1_icon--sz-small d1_icon--col-inherit"><circle cx="12" cy="12" r="10"></circle>
# <line x1="2" y1="12" x2="22" y2="12"></line>
# <path d="M12 2a15.3 15.3 0 0 1 4 10 15.3 15.3 0 0 1-4 10 15.3 15.3 0 0 1-4-10 15.3 15.3 0 0 1 4-10z"></path></svg>
# </span><p class="d1_menu-item__sub-item-name">About DataONE</p></a>
#           </li>
#
#
#
#
#
#
#           <li class="d1_menu-item__sub-item d1_menu-item__sub-item--has-icon">
#             <a class="d1_menu-item__sub-link" href="/profile" title="Summary of Holdings" id="metrics__sub-link"><span class="d1_menu-item__sub-item-icon">
#
#
#
#
#
#
#
# <svg viewBox="0 0 24 24" class="d1_icon d1_icon--sz-small d1_icon--col-inherit"><line x1="18" y1="20" x2="18" y2="10"></line>
# <line x1="12" y1="20" x2="12" y2="4"></line>
# <line x1="6" y1="20" x2="6" y2="14"></line></svg>
# </span><p class="d1_menu-item__sub-item-name">Metrics</p></a>
#           </li>
#
#
#
#
#
#
#           <li class="d1_menu-item__sub-item d1_menu-item__sub-item--has-icon">
#             <a class="d1_menu-item__sub-link" href="https://dataone.org/contact/" title="Contact" id="contact__sub-link"><span class="d1_menu-item__sub-item-icon">
#
#
#
#
#
#
#
# <svg viewBox="0 0 24 24" class="d1_icon d1_icon--sz-small d1_icon--col-inherit"><path d="M4 4h16c1.1 0 2 .9 2 2v12c0 1.1-.9 2-2 2H4c-1.1 0-2-.9-2-2V6c0-1.1.9-2 2-2z"></path>
# <polyline points="22,6 12,13 2,6"></polyline></svg>
# </span><p class="d1_menu-item__sub-item-name">Contact</p></a>
#           </li></ul>
#     <div class="d1_menu-item__sub-menu-arrow"></div></li>
# </ul>
#
#       <div class="d1_nav__secondary-nav">
#         <ul class="d1_nav__secondary-items" id="secondary-menu" aria-hidden="true">
#
#
#
#
#
#
# <li class="d1_menu-item d1_menu-item--dataone-plus-ad d1_menu-item--dropdown d1_menu-item--get-dataone-plus">
#
#
#
#     <button class="d1_menu-item__top-item" aria-haspopup="true" aria-expanded="false" aria-controls="get-dataone-plus__sub-menu"><span class="d1_menu-item__icon">
#
#
#
#
#
#
#
# ...
# <path d="M23 3a10.9 10.9 0 0 1-3.14 1.53 4.48 4.48 0 0 0-7.86 3v1A10.66 10.66 0 0 1 3 4s-4 9 5 13a11.64 11.64 0 0 1-7 2c9 5 20 0 20-11.5a4.5 4.5 0 0 0-.08-.83A7.72 7.72 0 0 0 23 3z"></path></svg>
# </a><a class="d1_contact-info__social-link" href="https://vimeo.com/channels/dataone" title="DataONE onvimeo">
#
#
#
#
#
#
#
# <svg viewBox="0 0 24 24" class="d1_icon d1_icon--col-inherit">
#
# <path d="M23 6a22 22 0 01-4.6 10.3c-3 4.5-5.6 6.7-7.7 6.7-1.3 0-2.4-1.4-3.3-4.1l-1.8-7.5C5 8.6 4.2 7.3 3.5 7.3c-.2 0-1.2 1.2-1.2 1.2L1 7s3.4-6 6.3-6C9 1 10 2.5 10.4 5.4l1 5.8c.4 2.6 1 3.8 1.6 3.8.5 0 1.2-.7 2.1-2.4.8-1.5 1.3-3.7 1.4-4.6 0-1.1-.5-2-1.4-2-.4 0-1 .1-1.4.9 1-3 2.9-5.9 6-5.9C22 1 23.1 2.8 23 6z"></path></svg>
# </a><a class="d1_contact-info__social-link" href="mailto:support@dataone.org" title="Email DataONE">
#
#
#
#
#
#
#
# <svg viewBox="0 0 24 24" class="d1_icon d1_icon--col-inherit"><path d="M4 4h16c1.1 0 2 .9 2 2v12c0 1.1-.9 2-2 2H4c-1.1 0-2-.9-2-2V6c0-1.1.9-2 2-2z"></path>
# <polyline points="22,6 12,13 2,6"></polyline></svg>
# </a>
#       <a class="d1_contact-info__social-link" href="https://slack.dataone.org" title="Email DataONE">
#
#
#
#
#
#
#
# <svg viewBox="0 0 24 24" class="d1_icon d1_icon--col-inherit"><path d="M14.5 10c-.83 0-1.5-.67-1.5-1.5v-5c0-.83.67-1.5 1.5-1.5s1.5.67 1.5 1.5v5c0 .83-.67 1.5-1.5 1.5z"></path>
# <path d="M20.5 10H19V8.5c0-.83.67-1.5 1.5-1.5s1.5.67 1.5 1.5-.67 1.5-1.5 1.5z"></path>
# <path d="M9.5 14c.83 0 1.5.67 1.5 1.5v5c0 .83-.67 1.5-1.5 1.5S8 21.33 8 20.5v-5c0-.83.67-1.5 1.5-1.5z"></path>
# <path d="M3.5 14H5v1.5c0 .83-.67 1.5-1.5 1.5S2 16.33 2 15.5 2.67 14 3.5 14z"></path>
# <path d="M14 14.5c0-.83.67-1.5 1.5-1.5h5c.83 0 1.5.67 1.5 1.5s-.67 1.5-1.5 1.5h-5c-.83 0-1.5-.67-1.5-1.5z"></path>
# <path d="M15.5 19H14v1.5c0 .83.67 1.5 1.5 1.5s1.5-.67 1.5-1.5-.67-1.5-1.5-1.5z"></path>
# <path d="M10 9.5C10 8.67 9.33 8 8.5 8h-5C2.67 8 2 8.67 2 9.5S2.67 11 3.5 11h5c.83 0 1.5-.67 1.5-1.5z"></path>
# <path d="M8.5 5H10V3.5C10 2.67 9.33 2 8.5 2S7 2.67 7 3.5 7.67 5 8.5 5z"></path></svg>
# </a>
#       <a class="d1_contact-info__social-link" href="https://dataone.org/contact/" title="See DataONE's mailing address">
#
#
#
#
#
#
#
# <svg viewBox="0 0 24 24" class="d1_icon d1_icon--col-inherit"><path d="M21 10c0 7-9 13-9 13s-9-6-9-13a9 9 0 0 1 18 0z"></path>
# <circle cx="12" cy="10" r="3"></circle></svg>
# </a></div>
# </div></section>
#   </div>
#
#   <section class="d1_footer__mailing-list">
#     <div class="d1_footer__mailing-list-inner">
#       <h5 class="d1_footer__mailing-list-title">Join our mailing list</h5>
#
#
# <div id="join-form" class="d1_join-form d1_join-form--mailing-list-only">
#   <div id="mlb2-1647596" class="ml-form-embedContainer ml-subscribe-form ml-subscribe-form-1647596">
#     <div class="ml-form-align-center">
#       <div class="ml-form-embedWrapper embedForm">
#         <div class="ml-form-embedBody ml-form-embedBodyDefault row-form">
#           <div class="ml-form-embedContent" style="margin-bottom:0"></div>
#           <form class="ml-block-form" action="https://app.mailerlite.com/webforms/submit/b7u9a7" data-code="b7u9a7" method="post" target="_blank">
#             <div class="ml-form-formContent">
#               <div class="ml-form-fieldRow ml-last-item">
#                 <div class="ml-field-group ml-field-email ml-validate-email ml-validate-required">
#                   <input type="email" class="form-control" data-inputmask="" name="fields[email]" placeholder="ada.lovelace@example.com" autocomplete="email" id="newsletter-email" required="true" aria-required="true" pattern="[a-z0-9._%+-]+@[a-z0-9.-]+\.[a-z]{2,}$" aria-invalid="false">
#                   <label class="d1_join-form__label" for="newsletter-email">E-mail address (required)</label>
#                 </div>
#               </div>
#             </div>
#             <div class="ml-form-interestGroupsRow ml-block-groups">
#               <div class="ml-form-interestGroupsRowCheckbox last-group" style="">
#                 <label>
#                   <input type="checkbox" name="groups[]" value="76427432" zgotmplz="" aria-invalid="false">
#                   <div class="label-description">Join the waitlist for a Hosted Repository from DataONE</div>
#                 </label>
#               </div>
#               <div class="ml-form-interestGroupsRowCheckbox group" style="">
#                 <label>
#                   <input type="checkbox" name="groups[]" value="76427356" zgotmplz="" aria-invalid="false">
#                   <div class="label-description">Notify me when I can upgrade my DataONE Plus portal</div>
#                 </label>
#               </div>
#               <div class="ml-form-interestGroupsRowCheckbox group" style="">
#                 <label>
#                   <input type="checkbox" name="groups[]" value="9902726" checked="" aria-invalid="false">
#                   <div class="label-description">Subscribe to the community mailing list</div>
#                 </label>
#               </div>
#             </div>
#             <style type="text/css">
#               .ml-form-recaptcha {
#                 margin-bottom: 20px;
#                 float: left;
#               }
#               .ml-form-recaptcha.ml-error iframe {
#                 border: solid 1px red;
#               }
#               @media screen and (max-width:768px) {
#                 .ml-form-recaptcha {
#                   transform: scale(.77);
#                   -webkit-transform: scale(.77);
#                   transform-origin: 0 0;
#                   -webkit-transform-origin: 0 0;
#                 }
#               }
#             </style>
#             <input type="hidden" name="ml-submit" value="1" aria-invalid="false">
#             <div class="ml-form-embedSubmit">
#               <button type="submit" class="primary">Sign up</button>
#               <button disabled="disabled" style="display:none" type="button" class="loading">
#                 <div class="ml-form-embedSubmitLoad">
#                   <div></div>
#                   <div></div>
#                   <div></div>
#                   <div></div>
#                 </div>
#               </button>
#             </div>
#           </form>
#         </div>
#         <div class="ml-form-successBody row-success" style="display:none">
#           <div class="ml-form-successContent">
#             <p class="response-text">Please check your e-mail</p>
#           </div>
#         </div>
#       </div>
#     </div>
#   </div>
#   <script>
#     function ml_webform_success_1647596() {
#       var r = ml_jQuery || jQuery;
#       r(".ml-subscribe-form-1647596 .row-success").show(),
#       r(".ml-subscribe-form-1647596 .row-form").hide()
#     }
#   </script>
#   <img src="https://track.mailerlite.com/webforms/o/1647596/b7u9a7?v4a60e9ef938a7fa0240ac9ba567062cb" width="1" height="1" style="max-width:1px;max-height:1px;visibility:hidden;padding:0;margin:0;display:block" border="0">
#   <script src="https://static.mailerlite.com/js/w/webforms.min.js?v4a60e9ef938a7fa0240ac9ba567062cb" type="text/javascript"></script>
# </div>
#
#     </div>
#   </section>
#
#
#   <section class="d1_footer__plus-portals-footer">
#     <div class="d1_footer__logo">
#       <a class="d1_footer__button d1_footer__button--logo" href="https://dataone.org">
# <svg viewBox="0 0 490 109" width="143" height="32" preserveAspectRatio="xMinYMin slice" class="d1_logo d1_logo--subtle d1_logo--sz-larger">
#   <title>DataONE</title>
#
#   <g>
#     <path class="d1_logo__data" d="M85.014 46.38c13.316-7.251 54.107-14.185 53.727 22.269.154 9.03-.554 30.534.927 38.311h-18.173l-1.195-6.494h-.398c-4.529 5.433-11.525 8.291-19.974 7.917-25.49-.666-32.806-45.62 18.516-44.637.875-13.376-21.072-9.914-29.716-4.374zm104.66 0c13.316-7.251 54.107-14.185 53.724 22.269l.007.447c.127 9.273-.535 30.213.922 37.864h-18.172l-1.195-6.494h-.398c-4.53 5.433-11.526 8.291-19.974 7.917-25.49-.666-32.806-45.62 18.516-44.637.875-13.376-21.072-9.914-29.716-4.374zm-19.55-22.932v18.536h14.398v14.827h-14.398v22.093c.021 9.183.757 14.576 13.872 12.196l.132 15.224c-39.97 9.183-33.242-19.858-33.686-49.513h-8.586V41.984h8.586V27.95l19.682-4.501zM0 18.453c17.694-2.424 48.676-4.789 63.941 7.697 13.26 9.387 19.006 29.78 12.512 51.35C66.466 108.266 32.333 109.943 0 106.31zm119.108 57.882c-22.189-1.631-23.675 16.838-11.273 17.888 6.53.198 11.583-5.024 11.273-10.86zm104.66 0c-22.19-1.631-23.675 16.838-11.273 17.888 6.53.198 11.583-5.024 11.273-10.86zM57.486 63.64C59.1 37.956 41.79 29.163 20.296 32.918v58.527c1.724.4 4.512.4 7.031.4 17.395.056 29.02-8.833 30.16-28.204z"></path>
#
#     <path class="d1_logo__globe" d="M300.057 0l.804.008c33.62-.245 58.535 30.538 52.255 64.726-4.254 24.254-26.264 44.089-52.255 43.593-32.562.305-57.253-29.14-52.408-62.351C251.635 21.152 273.134.37 299.256.005l.801-.005zM269.33 21.06c-24.017 24.619-13.954 70.073 21.55 78.605 15.425 3.323 31.051-.743 41.869-12.389C356.365 62.86 346.706 17.57 311.812 8.77c-15.567-3.534-31.529.61-42.482 12.29zm32.627-9.646c.104.382.57.505.74.481.827-.114 1.55.352 2.36.318.564-.023 1.1.198 1.56.601.368.326.327.73.23 1.058-.093.32-.457.403-.847.419-.522.02-.977-.219-1.434-.336-.574-.146-1.172-.292-1.749-.435-.564-.14-1.193-.031-1.78-.031-.203-.284.382-.438.057-.758-.244-.24-.561-.419-.777-.255-.298.224-.756.198-.922.607.106.294.585.375.478.83-.346.19-.756.149-1.104.081-2.056-.398-2.3-.357-3.984.518-.398.206-.84.432-.816.83.031.506.644.639 1.032.717 1.19.242 2.318.723 3.59.82 0 .346-.02.643.006.935.036.395.291.598.65.611.366.016.62-.218.618-.5-.01-.684.26-1.067.886-1.34.497-.216.489-.386.291-1.029-.314-1.02.055-1.53 1.126-1.546.301-.006.683-.118.888.023.385.266.842.25 1.235.48 1.096.642 1.114.621 2.406.314.182-.044.294-.013.45.086.613.385 1.26.721 1.865 1.114.712.464 1.437.875 2.264 1.107.384.107.764.297 1.031.633.445.557 1.136.895 1.388 1.63.057.164.265.273.496.338.762.214 1.362.677 1.918 1.383-.598.265-1.07.127-1.52.153-.473.029-.951.04-1.424-.005-.359-.034-.608-.24-.598-.661.01-.43.003-.862.003-1.287-.291-.187-.551-.223-.811.042-.21.216-.489.089-.733.094-.733.018-1.468-.018-2.2.013-.62.026-1.225.14-1.685.63.19.27.473.151.694.13.512-.047.9.091 1.227.508.501.638 1.18.896 1.995.81.297-.032.595-.006.923-.006.083.347.203.706-.021.977-.2.242-.512.505-.795.534-.478.049-.824.33-1.237.47-.395.136-.86.35-1.068-.356-.101-.341-.504-.445-.86-.278-.58.273-1.073.703-1.767.76-.223.018-.445.351-.403.718.029.243.135.56-.07.735-.203.171-.512.328-.762.31-.374-.03-.553.419-.93.286-.14-.05-.278.044-.317.153-.205.602-.728.98-1.055 1.503-.385.617-.538 1.21-.473 1.885.068.685-.182 1.132-.816 1.39-1.07.437-1.968 1.146-2.842 1.865l-.58.479c-1.008.825-1.234 1.054-.504 2.645.397.87.665 1.755.605 2.742-.044.708-.431 1.158-.904 1.57-.133.114-.44.132-.587-.03-.154-.166.194-.21.179-.371-.018-.203.093-.45-.133-.591-.306-.196-.392-.529-.543-.818-.296-.573-.686-1.067-.66-1.82.026-.698-.722-1.093-1.426-1.286-.832-.227-1.653-.219-2.49-.237-.348-.008-.629.036-.917.312-.351.339-.816.503-1.351.48-.905-.04-1.814.025-2.719-.024-.532-.029-.966.143-1.398.388-.641.367-1.296.721-1.798 1.284-.273.307-.517.645-.543 1.07-.05.864-.34 1.695-.582 2.491-.247.82-.174 1.591-.18 2.378-.004.908 1.399 2.627 2.225 2.77.704.12 1.409-.05 1.988-.484.377-.282.77-.612.998-1.01.642-1.115 1.627-1.399 2.801-1.35.302.014.603.003.92.003.294.633.06 1.203-.223 1.76-.31.607-.679 1.19-.939 1.818-.08.192-.241.325-.285.53-.273 1.258.02 1.62 1.35 1.597.326-.005.659.104.989-.112.706-.464 1.208.19 1.8.372.603.188.707.779 1.032 1.188.107.132-.125.302-.156.437-.218.95-.777 1.833-.61 2.867.067.411-.175.882.15 1.231.507.544.985 1.133 1.788 1.304.64.139.868.17 1.328-.038.792-.36 1.723-.323 2.362.09.66.428 1.517.167 1.957-.491.158-.24.293-.521.395-.75.153-.344.33-.492.647-.651 1.11-.555 2.32-.86 3.41-1.482.326-.187.96-.408 1.262-.276.61.271 1.387.295 1.811.95.416.646 1.149.8 1.79.98.663.184 1.401.278 2.085-.102.132-.075.327-.057.49-.057.822-.005 1.643-.044 2.459.013.556.039 1.037.2 1.393.797a9.396 9.396 0 002.812 2.989c.63.43 1.22.609 1.954.624 1.572.034 2.954.524 4.09 1.714.475.497.437 1.244 1.063 1.663.543.362.971.893 1.2 1.563.205.6.772.867 1.323 1 .566.135 1.07.398 1.517.707.57.396 1.162.688 1.822.592 1.19-.172 2.097.354 2.934 1.054.267.224.501.279.831.258.452 1.812-.127 3.424-1.06 4.908-.883 1.403-1.634 2.87-2.175 4.42-.387 1.113-.938 2.13-1.502 3.138-.252.453-.527.914-.777 1.372-.694 1.276-1.933 1.841-3.077 2.552-1 .62-1.99 1.257-2.954 1.93-.772.538-1.226 1.39-1.785 2.119-.411.536-.79 1.041-1.388 1.377-.543.305-.962.792-1.44 1.182-.995.813-2.079 1.409-3.23 1.932-.29.133-.61.284-.816.518-1.062 1.205-2.487 1.775-3.905 2.333 ...
#
#     <path class="d1_logo__ne" d="M487.956 1.568v6.788h-43.53v42.17h42.398v6.867h-42.398v42.773h44.593v6.79h-51.782V1.569h50.719zm-124.524 0l61.682 92.105V1.568h6.288v105.389h-5.175l-61.836-92.112v92.112h-6.287V1.567h5.328z"></path>
#   </g>
# </svg>
# </a>
#     </div>
#     <div class="d1_footer__plus-message">
#       Powered by <a href="https://dataone.org/plus">DataONE Plus</a>
#     </div>
#   </section>
#
# </footer>
# </footer>
# <div class="auto-height-member" id="map-mode-extra-padding"></div>
#
#
# <div id="signinPopup" class="modal hide fade sign-in">
# 	<div class="modal-header center">
# 	    <button type="button" class="close" data-dismiss="modal" aria-hidden="true">×</button>
# 	    <h3>Sign In</h3>
#   	</div>
# 	<div class="modal-body">
# 		<div class="row-fluid">
#
# 				<div class="span5">
#
# 					<div class="orcid-signin">
# 						<a href="https://cn.dataone.org/portal/oauth?action=start&amp;target=https%3A%2F%2Fsearch.dataone.org%2Fview%2Fhttps%253A%252F%252Fpasta.lternet.edu%252Fpackage%252Fmetadata%252Feml%252Fknb-lter-cap%252F686%252F1" class="signin orcid-btn update-orcid-sign-in-url">
# 							<img src="/img/orcid_64x64.png">
# 							<span>Sign in with ORCID</span>
# 						</a>
# 					</div>
# 				</div>
#
# 				<span class="divider-text span1">OR</span>
# 				<div class="span6">
#
# 					<div class="well scroll-y">
# 						<a class="btn update-sign-in-url" href="https://cn.dataone.org/portal/startRequest?target=https%3A%2F%2Fsearch.dataone.org%2Fview%2Fhttps%253A%252F%252Fpasta.lternet.edu%252Fpackage%252Fmetadata%252Feml%252Fknb-lter-cap%252F686%252F1">Sign in with your University or Institution</a>
#
#
# 								<p>Some of the 100+ Universities and Institutions to choose from:</p>
# 								<div id="login-options"><ul>
# <li><img src="/img/Google-logo.png" title="Google" alt="Google"></li>
# <li>Long Term Ecological Research Network</li>
# <li>Oak Ridge National Laboratory</li>
# <li><a href="https://cn.dataone.org/portal/startRequest?target=https%3A%2F%2Fsearch.dataone.org%2Fview%2Fhttps%253A%252F%252Fpasta.lternet.edu%252Fpackage%252Fmetadata%252Feml%252Fknb-lter-cap%252F686%252F1">100+ more...</a></li>
# </ul></div>
#
# 					</div>
#
# 				</div>
#
# 		</div>
# 	</div>
#
# </div>
# <div id="signupPopup" class="modal hide fade">
# 	<div class="modal-header center">
# 	    <button type="button" class="close" data-dismiss="modal" aria-hidden="true">×</button>
# 	    <h3>Sign Up</h3>
#   	</div>
# 	<div class="modal-body center">
# 		<p class="subtitle subtle">View your data and access your identification code to upload content.</p>
#
# 			<p>There's no need to create a new account - just use your <a href="https://cn.dataone.org/portal/oauth?action=start&amp;target=https%3A%2F%2Fsearch.dataone.org%2Fview%2Fhttps%253A%252F%252Fpasta.lternet.edu%252Fpackage%252Fmetadata%252Feml%252Fknb-lter-cap%252F686%252F1">existing <img src="/img/orcid_64x64.png" class="icon-on-left icon"> ORCID account</a> now or <a href="https://cn.dataone.org/portal/oauth?action=start&amp;target=https%3A%2F%2Fsearch.dataone.org%2Fview%2Fhttps%253A%252F%252Fpasta.lternet.edu%252Fpackage%252Fmetadata%252Feml%252Fknb-lter-cap%252F686%252F1">create a new one</a>.</p>
# 			<div class="orcid-signin center">
# 				<a href="https://cn.dataone.org/portal/oauth?action=start&amp;target=https%3A%2F%2Fsearch.dataone.org%2Fview%2Fhttps%253A%252F%252Fpasta.lternet.edu%252Fpackage%252Fmetadata%252Feml%252Fknb-lter-cap%252F686%252F1" class="signin orcid-btn update-orcid-sign-in-url">
# 					<img src="/img/orcid_64x64.png">
# 					<span>Sign up with ORCID</span>
# 				</a>
# 			</div>
#
# 	</div>
#
# </div>
# </body></html>

# %% [markdown]
# The extracted JSON-LD

# %%
print(json.dumps(response["document"], indent=2))
# Out:
# [
#   {
#     "@context": {
#       "@vocab": "https://schema.org/"
#     },
#     "@type": "Dataset",
#     "@id": "https://dataone.org/datasets/https%3A%2F%2Fpasta.lternet.edu%2Fpackage%2Fmetadata%2Feml%2Fknb-lter-cap%2F686%2F1",
#     "datePublished": "2021-03-01T00:00:00Z",
#     "dateModified": "2021-03-01T20:45:34.873Z",
#     "publisher": {
#       "@type": "Organization",
#       "name": "LTER Network Member Node"
#     },
#     "identifier": "https://pasta.lternet.edu/package/metadata/eml/knb-lter-cap/686/1",
#     "url": "https://dataone.org/datasets/https%3A%2F%2Fpasta.lternet.edu%2Fpackage%2Fmetadata%2Feml%2Fknb-lter-cap%2F686%2F1",
#     "schemaVersion": "https://eml.ecoinformatics.org/eml-2.2.0",
#     "isAccessibleForFree": true,
#     "name": "Urban Ecological Infrastructure (UEI) in the greater Phoenix, Arizona metropolitan area and surrounding Sonoran desert region (2010-2017)",
#     "creator": [
#       {
#         "@type": "Person",
#         "name": "Jeffrey Brown"
#       },
#       {
#         "@type": "Person",
#         "name": "Kelli Larson"
#       },
#       {
#         "@type": "Person",
#         "name": "Susannah Lerman"
#       },
#       {
#         "@type": "Person",
#         "name": "Dan Childers"
#       },
#       {
#         "@type": "Person",
#         "name": "Riley Andrade"
#       },
#       {
#         "@type": "Person",
#         "name": "Heather Bateman"
#       },
#       {
#         "@type": "Person",
#         "name": "Sharon Hall"
#       },
#       {
#         "@type": "Person",
#         "name": "Paige Warren"
#       },
#       {
#         "@type": "Person",
#         "name": "Abigail York"
#       }
#     ],
#     "spatialCoverage": {
#       "@type": "Place",
#       "additionalProperty": [
#         {
#           "@type": "PropertyValue",
#           "additionalType": "http://dbpedia.org/resource/Coordinate_reference_system",
#           "name": "Coordinate Reference System",
#           "value": "http://www.opengis.net/def/crs/OGC/1.3/CRS84"
#         }
#       ],
#       "geo": {
#         "@type": "GeoShape",
#         "box": "-112.82705, 33.118004 -111.47679, 33.987247"
#       },
#       "subjectOf": {
#         "@type": "CreativeWork",
#         "fileFormat": "application/vnd.geo+json",
#         "text": "{\"type\":\"Feature\",\"properties\":{},\"geometry\":{\"type\":\"Polygon\",\"coordinates\":[[[-112.82705,33.118004],[-111.47679,33.118004],[-111.47679,33.987247],[-112.82705,33.987247],[-112.82705,33.118004]]]}}"
#       }
#     },
#     "temporalCoverage": "2020-06-26T00:00:00Z/2017-08-01T00:00:00Z",
#     "description": "Urban ecological infrastructure (UEI) encompasses all infrastructure in a city that supports ecological structure and function, and by extension, provides ecosystem services to urban residents and is a broad, all-encompassing concept for \"nature in cities\". This idea includes commonly recognized forms of infrastructure, such as parks, residential yards, community gardens, lakes and rivers, and street trees. But UEI also includes less recognized forms, such as vacant lots, agricultural fields, canals, and water retention basins. Despite being widely recognized as important to urban landscapes, the wide variety, and various forms of urban ecological infrastructure are rarely documented in a single source. To address this, we consolidated various aquatic, terrestrial, and wetland UEI throughout the Phoenix Metropolitan area so researchers can incorporate this UEI into project designs and models. Since people\u2019s perceptions of UEI differ not only by the three broad classifications but also by the individual characteristics of UEI, each feature is classified not only as aquatic, terrestrial, or wetlands but also given on of fifteen unique classifications. Incorporation of UEI into both planning and research design can promote practices that increase both biodiversity and human well-being while also possibly limiting negative landscape perceptions.",
#     "keywords": "urban, land use, landsat, land surface properties, land cover, urban design, parks and rivers, residential landscapes and neighborhoods, land use and land cover change, human-environment interactions, ecosystem disservices, ecosystem services, urban ecological infrastructure, urban planning, urban nature, cap lter, cap, caplter, central arizona phoenix long term ecological research, arizona, az, arid land"
#   }
# ]
