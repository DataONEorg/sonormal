# %% [markdown]
# # Get JSON-LD from a source URL

# %%
import json
import sonormal.getjsonld

sonormal.installDocumentLoader()

url = "https://datadavev.github.io/examples/jsonld/ex01.html"

jsonld, response = await sonormal.getjsonld.downloadJsonAsync(url)

# %%
response_summary = sonormal.getjsonld.responseSummary(response)
print(json.dumps(response_summary, indent=2))
# Out:
# {
#   "request": {
#     "url": "https://datadavev.github.io/examples/jsonld/ex01.html",
#     "headers": {
#       "User-Agent": "python-requests/2.25.1",
#       "Accept-Encoding": "gzip, deflate",
#       "Accept": "application/ld+json;q=1.0, applcation/json;q=0.9, text/html;q=0.8, application/xml+xhtml;q=0.7",
#       "Connection": "keep-alive"
#     }
#   },
#   "responses": [
#     {
#       "url": "https://datadavev.github.io/examples/jsonld/ex01.html",
#       "status_code": 200,
#       "result": "<< body >>",
#       "elapsed": 0.079823,
#       "headers": {
#         "connection": "keep-alive",
#         "content-length": "342",
#         "server": "GitHub.com",
#         "content-type": "text/html; charset=utf-8",
#         "last-modified": "Tue, 23 Feb 2021 20:40:09 GMT",
#         "access-control-allow-origin": "*",
#         "etag": "W/\"60356829-271\"",
#         "expires": "Tue, 02 Mar 2021 14:47:57 GMT",
#         "cache-control": "max-age=600",
#         "content-encoding": "gzip",
#         "x-proxy-cache": "MISS",
#         "x-github-request-id": "BD5A:5532:0FDD:235D:603E4DC5",
#         "accept-ranges": "bytes",
#         "date": "Tue, 02 Mar 2021 16:31:53 GMT",
#         "via": "1.1 varnish",
#         "age": "0",
#         "x-served-by": "cache-dca17729-DCA",
#         "x-cache": "HIT",
#         "x-cache-hits": "1",
#         "x-timer": "S1614702714.928813,VS0,VE9",
#         "vary": "Accept-Encoding",
#         "x-fastly-request-id": "547c89466ed02a42be3f331d04b19d3e8ef563de"
#       },
#       "content_type": [
#         "text/html; charset=utf-8"
#       ],
#       "last_modified": [
#         "Tue, 23 Feb 2021 20:40:09 GMT"
#       ]
#     }
#   ],
#   "resources_loaded": []
# }

# %% [markdown]
# The downloaded HTML:

# %%
print(response.text)
# Out:
# <!DOCTYPE html>
# <html>
#
# <head>
#     <title>Hello JSON-LD</title>
#     <link rel="stylesheet" href="../css/common.css" />
#     <script src="../js/common.js"></script>
#     <script type="application/ld+json">
#             {
#                 "@context":{
#                     "@vocab":"https://example.net/"
#                 },
#                 "@id": "http://data.example.net/example_01",
#                 "name": "This is example 01"
#             }
#         </script>
# </head>
#
# <body>
#     <p>Hello JSON-LD.</p>
#     <p><a href="https://github.com/datadavev/examples/blob/main/docs/jsonld/ex01.html">View the source.</a></p>
# </body>
#
# </html>

# %% [markdown]
# The extracted JSON-LD

# %%
print(json.dumps(jsonld, indent=2))
# Out:
# {
#   "@context": {
#     "@vocab": "https://example.net/"
#   },
#   "@id": "http://data.example.net/example_01",
#   "name": "This is example 01"
# }

# %% [markdown]
# Retrieve from a service with a few redirects

# %%
url = "https://earthref.org/MagIC/17099"
#url = "https://search.dataone.org/view/https%3A%2F%2Fpasta.lternet.edu%2Fpackage%2Fmetadata%2Feml%2Fknb-lter-cap%2F686%2F1"
jsonld, response = await sonormal.getjsonld.downloadJsonAsync(url)

response_summary = sonormal.getjsonld.responseSummary(response)
print(json.dumps(response_summary, indent=2))
# Out:
# No JSON-LD in plain source https://earthref.org/MagIC/17099
# IN: %s https://earthref.org/MagIC/17099
# OT: %s https://earthref.org/MagIC/17099
# IN: %s http://earthref.org/MagIC/17099/
# OT: %s http://earthref.org/MagIC/17099/
# IN: %s https://earthref.org/MagIC/17099/
# OT: %s https://earthref.org/MagIC/17099/
# IN: %s https://www2.earthref.org/MagIC/17099
# OT: %s https://www2.earthref.org/MagIC/17099
# IN: %s https://www2.earthref.org/3c54dae4bcf905f42f5c9e7667736fd08ffd7826.css?meteor_css_resource=true
# IN: %s https://www2.earthref.org/lib/semantic-ui/compiled/2.4.2/semantic.css
# IN: %s https://www2.earthref.org/6be857144aa9f22087118eaa43bbb0bbecb2f9f9.js?meteor_js_resource=true
# OT: %s https://www2.earthref.org/3c54dae4bcf905f42f5c9e7667736fd08ffd7826.css?meteor_css_resource=true
# OT: %s https://www2.earthref.org/6be857144aa9f22087118eaa43bbb0bbecb2f9f9.js?meteor_js_resource=true
# OT: %s https://www2.earthref.org/lib/semantic-ui/compiled/2.4.2/semantic.css
# IN: %s https://fonts.googleapis.com/css?family=Open%20Sans:400,700,400italic,700italic&subset=latin
# OT: %s https://fonts.googleapis.com/css?family=Open%20Sans:400,700,400italic,700italic&subset=latin
# IN: %s https://maps.googleapis.com/maps/api/js?v=3&key=AIzaSyBLZOmrD0zBidUXezxmNRHcpPp5cA45pUQ&callback=GoogleMaps.initialize
# IN: %s https://fonts.gstatic.com/s/opensans/v18/mem8YaGs126MiZpBA-UFVZ0bf8pkAg.woff2
# IN: %s https://fonts.gstatic.com/s/opensans/v18/mem5YaGs126MiZpBA-UN7rgOUuhpKKSTjw.woff2
# IN: %s https://www2.earthref.org/lib/semantic-ui/themes/default/assets/fonts/icons.woff2
# IN: %s data:application/x-font-ttf;charset=utf-8;base64,...
# IN: %s data:application/font-woff;charset=utf-8;base64,...
# IN: %s https://www2.earthref.org/MagIC/FIESTA.png
# OT: %s https://maps.googleapis.com/maps/api/js?v=3&key=AIzaSyBLZOmrD0zBidUXezxmNRHcpPp5cA45pUQ&callback=GoogleMaps.initialize
# OT: %s data:application/x-font-ttf;charset=utf-8;base64,...
# OT: %s data:application/font-woff;charset=utf-8;base64,...
# OT: %s https://www2.earthref.org/lib/semantic-ui/themes/default/assets/fonts/icons.woff2
# OT: %s https://fonts.gstatic.com/s/opensans/v18/mem8YaGs126MiZpBA-UFVZ0bf8pkAg.woff2
# OT: %s https://fonts.gstatic.com/s/opensans/v18/mem5YaGs126MiZpBA-UN7rgOUuhpKKSTjw.woff2
# OT: %s https://www2.earthref.org/MagIC/FIESTA.png
# IN: %s https://www2.earthref.org/sockjs/info?cb=b60n0cfvip
# OT: %s https://www2.earthref.org/sockjs/info?cb=b60n0cfvip
# {
#   "request": {
#     "url": "https://earthref.org/MagIC/17099",
#     "headers": {
#       "upgrade-insecure-requests": "1",
#       "user-agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_16_0) AppleWebKit/537.36 (KHTML, like Gecko) HeadlessChrome/71.0.3542.0 Safari/537.36",
#       "accept": "application/ld+json;q=1.0, applcation/json;q=0.9, text/html;q=0.8, application/xml+xhtml;q=0.7"
#     }
#   },
#   "responses": [
#     {
#       "url": "https://earthref.org/MagIC/17099",
#       "status_code": 301,
#       "result": "<< body >>",
#       "elapsed": 0.18765,
#       "headers": {
#         "server": "nginx/1.14.0 (Ubuntu)",
#         "date": "Tue, 02 Mar 2021 16:31:55 GMT",
#         "content-type": "text/html; charset=iso-8859-1",
#         "content-length": "240",
#         "connection": "keep-alive",
#         "location": "http://earthref.org/MagIC/17099/",
#         "cache-control": "max-age=0",
#         "expires": "Tue, 02 Mar 2021 16:31:55 GMT",
#         "strict-transport-security": "max-age=63072000; includeSubdomains;"
#       },
#       "content_type": [
#         "text/html; charset=iso-8859-1"
#       ],
#       "last_modified": [
#         "-"
#       ]
#     },
#     {
#       "url": "http://earthref.org/MagIC/17099/",
#       "status_code": 307,
#       "result": "<< body >>",
#       "elapsed": 0.000967,
#       "headers": {
#         "location": "https://earthref.org/MagIC/17099/",
#         "non-authoritative-reason": "HSTS"
#       },
#       "content_type": [
#         "-"
#       ],
#       "last_modified": [
#         "-"
#       ]
#     },
#     {
#       "url": "https://earthref.org/MagIC/17099/",
#       "status_code": 302,
#       "result": "<< body >>",
#       "elapsed": 0.14417,
#       "headers": {
#         "server": "nginx/1.14.0 (Ubuntu)",
#         "date": "Tue, 02 Mar 2021 16:31:55 GMT",
#         "content-type": "text/html; charset=iso-8859-1",
#         "content-length": "221",
#         "connection": "keep-alive",
#         "location": "https://www2.earthref.org/MagIC/17099",
#         "cache-control": "max-age=0",
#         "expires": "Tue, 02 Mar 2021 16:31:55 GMT",
#         "strict-transport-security": "max-age=63072000; includeSubdomains;"
#       },
#       "content_type": [
#         "text/html; charset=iso-8859-1"
#       ],
#       "last_modified": [
#         "-"
#       ]
#     },
#     {
#       "url": "https://www2.earthref.org/MagIC/17099",
#       "status_code": 200,
#       "result": "<< body >>",
#       "elapsed": 0.067881,
#       "headers": {
#         "status": "200",
#         "content-encoding": "gzip",
#         "content-type": "text/html; charset=utf-8",
#         "date": "Tue, 02 Mar 2021 16:31:55 GMT",
#         "set-cookie": "galaxy-sticky=hGPuyoaYsfQSQHCof-pbcrj; Path=/; HttpOnly; SameSite=Lax",
#         "vary": "Accept-Encoding",
#         "content-length": "850"
#       },
#       "content_type": [
#         "text/html; charset=utf-8"
#       ],
#       "last_modified": [
#         "-"
#       ]
#     }
#   ],
#   "resources_loaded": [
#     "https://earthref.org/MagIC/17099",
#     "http://earthref.org/MagIC/17099/",
#     "https://earthref.org/MagIC/17099/",
#     "https://www2.earthref.org/MagIC/17099",
#     "https://www2.earthref.org/3c54dae4bcf905f42f5c9e7667736fd08ffd7826.css?meteor_css_resource=true",
#     "https://www2.earthref.org/lib/semantic-ui/compiled/2.4.2/semantic.css",
#     "https://www2.earthref.org/6be857144aa9f22087118eaa43bbb0bbecb2f9f9.js?meteor_js_resource=true",
#     "https://fonts.googleapis.com/css?family=Open%20Sans:400,700,400italic,700italic&subset=latin",
#     "https://maps.googleapis.com/maps/api/js?v=3&key=AIzaSyBLZOmrD0zBidUXezxmNRHcpPp5cA45pUQ&callback=GoogleMaps.initialize",
#     "https://fonts.gstatic.com/s/opensans/v18/mem8YaGs126MiZpBA-UFVZ0bf8pkAg.woff2",
#     "https://fonts.gstatic.com/s/opensans/v18/mem5YaGs126MiZpBA-UN7rgOUuhpKKSTjw.woff2",
#     "https://www2.earthref.org/lib/semantic-ui/themes/default/assets/fonts/icons.woff2",
#     "data:application/x-font-ttf;charset=utf-8;base64,...",
#     "data:application/font-woff;charset=utf-8;base64,...",
#     "https://www2.earthref.org/MagIC/FIESTA.png",
#     "https://www2.earthref.org/sockjs/info?cb=b60n0cfvip"
#   ]
# }

# %% [markdown]
# The downloaded HTML:

# %%
print(response.text)
# Out:
# <!DOCTYPE html><html><head>
#   <link rel="stylesheet" type="text/css" class="__meteor-css__" href="/3c54dae4bcf905f42f5c9e7667736fd08ffd7826.css?meteor_css_resource=true">
# <link rel="stylesheet" href="/lib/semantic-ui/compiled/2.4.2/semantic.css">
#
# <title>MagIC Search | EarthRef.org</title><link rel="canonical" href="https://earthref.org/MagIC/17099" data-react-helmet="true"><script id="schemaorg" type="application/ld+json" data-react-helmet="true">{
#   "@context": {
#     "@vocab": "https://schema.org/",
#     "geosci-time": "http://schema.geoschemas.org/contexts/temporal#"
#   },
#   "@type": "Dataset",
#   "identifier": "http://dx.doi.org/10.7288/V4/MAGIC/{cid}",
#   "url": "https://earthref.org/MagIC/{cid}",
#   "isAccessibleForFree": true,
#   "license": "https://creativecommons.org/licenses/by/4.0/",
#   "provider": {
#     "@id": "https://earthref.org/MagIC",
#     "type": "Organization",
#     "legalName": "Magnetics Information Consortium (MagIC) Data Repository",
#     "name": "MagIC",
#     "url": "https://earthref.org/MagIC"
#   },
#   "publisher": {
#     "@id": "https//earthref.org/MagIC"
#   },
#   "sdPublisher": "EarthRef.org",
#   "sdLicense": "https://creativecommons.org/licenses/by/4.0/",
#   "sdDatePublished": "2021-03-02T16:31:57.278Z",
#   "labNames": "Paleomagnetic Lab (Helmholtz Centre Potsdam, Germany)",
#   "distribution": {
#     "@type": "DataDownload",
#     "contentUrl": "https://earthref.org/MagIC/download/{cid}/magic_contribution_{cid}.txt",
#     "encodingFormat": [
#       "text/plain; application=earthref-tsv",
#       "EarthRef-tsv-Multipart"
#     ]
#   },
#   "version": 2,
#   "contributor": "Niels Meijer",
#   "dateModified": "2021-02-24T08:04:30.134Z",
#   "citation": "<b>Niels Meijer, Guillaume Dupont‐Nivet, Natasha Barbolini, Amber Woutersen, Alexander Rohrmann, Yang Zhang, Xiang‐Jun Liu, Alexis Licht, Hemmo A. Abels, Carina Hoorn, Rik Tjallingii, Christoff Andermann, Michael Dietze, Norbert Nowaczyk (2021).</b> Loess‐like dust appearance at 40 Ma in central China. <i>Paleoceanography and Paleoclimatology. doi:<a href='//dx.doi.org/10.1029/2020PA003993'>10.1029/2020PA003993</a>.</i>",
#   "sameAs": [
#     "https://doi.org/10.1029/2020PA003993"
#   ],
#   "name": "<b>Niels Meijer, Guillaume Dupont‐Nivet, Natasha Barbolini, Amber Woutersen, Alexander Rohrmann, Yang Zhang, Xiang‐Jun Liu, Alexis Licht, Hemmo A. Abels, Carina Hoorn, Rik Tjallingii, Christoff Andermann, Michael Dietze, Norbert Nowaczyk (2021).</b> Loess‐like dust appearance at 40 Ma in central China. <i>Paleoceanography and Paleoclimatology. doi:<a href='//dx.doi.org/10.1029/2020PA003993'>10.1029/2020PA003993</a>.</i> (Dataset)",
#   "description": "Paleomagnetic, rock magnetic, or geomagnetic data found in the MagIC data repository from a paper titled: <b>Niels Meijer, Guillaume Dupont‐Nivet, Natasha Barbolini, Amber Woutersen, Alexander Rohrmann, Yang Zhang, Xiang‐Jun Liu, Alexis Licht, Hemmo A. Abels, Carina Hoorn, Rik Tjallingii, Christoff Andermann, Michael Dietze, Norbert Nowaczyk (2021).</b> Loess‐like dust appearance at 40 Ma in central China. <i>Paleoceanography and Paleoclimatology. doi:<a href='//dx.doi.org/10.1029/2020PA003993'>10.1029/2020PA003993</a>.</i>",
#   "datePublished": "2021-02-24T08:04:30.134Z",
#   "spatialCoverage": {
#     "@type": "Place",
#     "geo": [
#       {
#         "@type": "GeoShape",
#         "box": "36.52 102.105 36.51 102.1"
#       },
#       {
#         "@type": "GeoCoordinates",
#         "latitude": 36.5183,
#         "longitude": 102.104
#       }
#     ]
#   },
#   "temporalCoverage": {
#     "@type": "DateTime",
#     "startDate": -33998051,
#     "endDate": -52998051
#   },
#   "geosci-time": {
#     "@type": "time:Instant",
#     "time:inTimePosition": {
#       "@type": "time:ProperInterval",
#       "time:hasBeginning": {
#         "time:hasTRS": {
#           "@id": "geosci-time:BeforePresent"
#         },
#         "time:numericPosition": {
#           "@value": 34000000,
#           "@type": "xsd:decimal"
#         }
#       },
#       "time:hasEnd": {
#         "time:hasTRS": {
#           "@id": "geosci-time:BeforePresent"
#         },
#         "time:numericPosition": {
#           "@value": 53000000,
#           "@type": "xsd:decimal"
#         }
#       }
#     }
#   },
#   "variableMeasured": [
#     {
#       "@type": "PropertyValue",
#       "name": "Specimen X Direction Azimuth",
#       "description": "Azimuth of specimens’s x direction measured clockwise from north",
#       "minValue": 18,
#       "maxValue": 350,
#       "unitText": "Degrees"
#     },
#     {
#       "@type": "PropertyValue",
#       "name": "Specimen X Direction Dip",
#       "description": "Dip of specimens’s x direction from the horizontal increasing downward",
#       "minValue": -108,
#       "maxValue": -30,
#       "unitText": "Degrees"
#     },
#     {
#       "@type": "PropertyValue",
#       "name": "Lab Treatment DC Field",
#       "description": "Applied DC field",
#       "minValue": 0,
#       "maxValue": 0,
#       "unitText": "T"
#     },
#     {
#       "@type": "PropertyValue",
#       "name": "Bedding Dip Direction",
#       "description": "Direction of the dip of a paleo-horizontal plane of bedding (strike + 90 degrees)",
#       "minValue": 0,
#       "maxValue": 90,
#       "unitText": "Degrees"
#     },
#     {
#       "@type": "PropertyValue",
#       "name": "Latitude",
#       "description": "Sample geographic location, Latitude",
#       "minValue": 36.5183,
#       "maxValue": 36.5183,
#       "unitText": "Degrees"
#     },
#     {
#       "@type": "PropertyValue",
#       "name": "Stratigraphic Height",
#       "description": "Sample geographic location, Stratigraphic height",
#       "minValue": 6.1,
#       "maxValue": 61.3,
#       "unitText": "m"
#     },
#     {
#       "@type": "PropertyValue",
#       "name": "Inclination",
#       "description": "Directions in specimen coordinates, Inclination",
#       "minValue": -86.4255,
#       "maxValue": 87.1356,
#       "unitText": "Degrees"
#     },
#     {
#       "@type": "PropertyValue",
#       "name": "Lab Treatment Orientation Theta",
#       "description": "Orientation of the lab field with respect to the specimen during treatment",
#       "minValue": 0,
#       "maxValue": 0,
#       "unitText": "Degrees"
#     },
#     {
#       "@type": "PropertyValue",
#       "name": "Lab Treatment AC Field",
#       "description": "Peak field in AC demagnetization experiment",
#       "minValue": 0,
#       "maxValue": 0,
#       "unitText": "T"
#     },
#     {
#       "@type": "PropertyValue",
#       "name": "Volume",
#       "description": "Specimen volume",
#       "minValue": 0.00001,
#       "maxValue": 0.00001,
#       "unitText": "m^3"
#     },
#     {
#       "@type": "PropertyValue",
#       "name": "Magnetization Volume",
#       "description": "Measured intensity of magnetization, Volume normalized",
#       "minValue": 0.00003365752,
#       "maxValue": 0.009622669,
#       "unitText": "A/m"
#     },
#     {
#       "@type": "PropertyValue",
#       "name": "Longitude",
#       "description": "Sample geographic location, Longitude",
#       "minValue": 102.104,
#       "maxValue": 102.104,
#       "unitText": "Degrees"
#     },
#     {
#       "@type": "PropertyValue",
#       "name": "Measurement Temperature",
#       "description": "Temperature",
#       "minValue": 293,
#       "maxValue": 293,
#       "unitText": "K"
#     },
#     {
#       "@type": "PropertyValue",
#       "name": "Circular Standard Deviation",
#       "description": "Circular standard deviation in measurements",
#       "minValue": 0.1,
#       "maxValue": 0.1,
#       "unitText": "Degrees"
#     },
#     {
#       "@type": "PropertyValue",
#       "name": "Creation Timestamp",
#       "description": "UTC Date and time of when image was taken or created",
#       "minValue": 1546300800000,
#       "maxValue": 1546300800000
#     },
#     {
#       "@type": "PropertyValue",
#       "name": "Declination",
#       "description": "Directions in specimen coordinates, Declination",
#       "minValue": 1.12987,
#       "maxValue": 359.703,
#       "unitText": "Degrees"
#     },
#     {
#       "@type": "PropertyValue",
#       "name": "Lab Treatment Orientation Phi",
#       "description": "Orientation of the lab field with respect to the specimen during treatment",
#       "minValue": 0,
#       "maxValue": 0,
#       "unitText": "Degrees"
#     },
#     {
#       "@type": "PropertyValue",
#       "name": "Geographic Precision",
#       "description": "Site geographic location, Precision in latitude and longitude",
#       "minValue": 0.0001,
#       "maxValue": 0.0001,
#       "unitText": "Degrees"
#     },
#     {
#       "@type": "PropertyValue",
#       "name": "Bedding Dip",
#       "description": "Dip of the bedding as measured in the bed dip direction (dip right of strike)",
#       "minValue": 0,
#       "maxValue": 0,
#       "unitText": "Degrees"
#     },
#     {
#       "@type": "PropertyValue",
#       "name": "Lab Treatment Temperature",
#       "description": "Demagnetization temperature",
#       "minValue": 393,
#       "maxValue": 923,
#       "unitText": "K"
#     },
#     {
#       "@type": "PropertyValue",
#       "name": "Lab Treatment Step Index",
#       "description": "An integer that increases by one for each measurement done during an experiment",
#       "minValue": 1,
#       "maxValue": 13
#     },
#     {
#       "@type": "PropertyValue",
#       "name": "Magnetic Moment",
#       "description": "Measured magnetic moment",
#       "minValue": 3.365752e-10,
#       "maxValue": 9.622669e-8,
#       "unitText": "Am^2"
#     }
#   ]
# }</script></head>
# <body>
#   <script type="text/javascript">__meteor_runtime_config__ = JSON.parse(decodeURIComponent("%7B%22meteorRelease%22%3A%22METEOR%401.12.1%22%2C%22gitCommitHash%22%3A%22e1c23a6f34a610243567caf8a3fe8161a656dba5%22%2C%22meteorEnv%22%3A%7B%22NODE_ENV%22%3A%22production%22%2C%22TEST_METADATA%22%3A%22%7B%7D%22%7D%2C%22PUBLIC_SETTINGS%22%3A%7B%22google%22%3A%7B%22apiKey%22%3A%22AIzaSyCbqrAY9ydq2Np1thfXwcQkbEnWGHVYAo8%22%7D%7D%2C%22ROOT_URL%22%3A%22https%3A%2F%2Fwww2.earthref.org%22%2C%22ROOT_URL_PATH_PREFIX%22%3A%22%22%2C%22autoupdate%22%3A%7B%22versions%22%3A%7B%22web.browser%22%3A%7B%22version%22%3A%2202c6447b716c68d28692c15a8fc6942d8ed4a819%22%2C%22versionRefreshable%22%3A%22554a7497175026f1c0b2a3f428090d60c0bc2053%22%2C%22versionNonRefreshable%22%3A%229c70c915aae461a18a0fd31e1cbabb5bef788f17%22%7D%2C%22web.browser.legacy%22%3A%7B%22version%22%3A%220e3bb27de602e3c6caf5a147c1ee6e317efcb340%22%2C%22versionRefreshable%22%3A%22554a7497175026f1c0b2a3f428090d60c0bc2053%22%2C%22versionNonRefreshable%22%3A%22504d35a5d157e720b2570a86ef8034923524a500%22%7D%7D%2C%22autoupdateVersion%22%3Anull%2C%22autoupdateVersionRefreshable%22%3Anull%2C%22autoupdateVersionCordova%22%3Anull%2C%22appId%22%3A%22175gf241sasqm5g2fmsq%22%7D%2C%22appId%22%3A%22175gf241sasqm5g2fmsq%22%2C%22isModern%22%3Atrue%7D"))</script>
#
#   <script type="text/javascript" src="/6be857144aa9f22087118eaa43bbb0bbecb2f9f9.js?meteor_js_resource=true"></script><script type="text/javascript" src="https://maps.googleapis.com/maps/api/js?v=3&amp;key=AIzaSyBLZOmrD0zBidUXezxmNRHcpPp5cA45pUQ&amp;callback=GoogleMaps.initialize"></script>
#
#
#
# <div id="react-root"><div class="layout pushable"><div class="ui vertical inverted left sidebar menu"><div class="sidebar-navigation"><a class="green item" href="https://earthref.org/">EarthRef.org</a><a class="active purple item" href="/MagIC">MagIC</a><a class="orange item" href="https://earthref.org/GERM/">GERM</a><a class="teal item" href="https://earthref.org/SBN/">SBN</a><a class="red item" href="https://earthref.org/FeMO/">FeMO</a><a class="pink item" href="https://earthref.org/SCC/">SCC</a><a class="blue item" href="https://earthref.org/ERESE/">ERESE</a><a class="green item" href="https://earthref.org/ERDA/">ERDA</a><a class="green item" href="https://earthref.org/ERR/">References</a><a class="green item" href="https://earthref.org/ERML/">Users</a></div></div><div class="pusher"><div class="ui main layout-content full-width"><div class="ui modal"><h1 class="ui centered header">Beta Site</h1><div class="content"><div class="description"><div class="ui header">The EarthRef Beta Site is under active development.</div><p>Some features are disabled, some are incomplete, and some are mocked-up. Work is in progress.</p><p>For questions and comments, please contact Nick (<a href="mailto:njarboe@ucsd.edu">njarboe@ucsd.edu</a>) or Rupert (<a href="mailto:rminnett@earthref.org">rminnett@earthref.org</a>).</p></div></div><div class="actions"><div class="ui purple right labeled icon approve button">OK<i class="checkmark icon"></i></div></div></div><div class="ui modal"><h1 class="ui centered header">Temporary Safari Warning</h1><div class="content"><div class="description"><div class="ui header">The EarthRef MagIC Site is under active development.</div><p>While we fix a few issues with features that are incompatible with Safari, please use Chrome or Firefox.</p><p>For questions and comments, please contact Nick (<a href="mailto:njarboe@ucsd.edu">njarboe@ucsd.edu</a>) or Rupert (<a href="mailto:rminnett@earthref.org">rminnett@earthref.org</a>).</p></div></div><div class="actions"><div class="ui purple right labeled icon approve button">OK<i class="checkmark icon"></i></div></div></div><style>
#           a, a:hover {
#             color: #792f91;
#           }
#         </style><a class="ui menu basic button page-logo purple" href="/MagIC">M</a><a href="/MagIC"><h1 class="page-title">Magnetics Information Consortium (MagIC)</h1><h4 class="page-subtitle">Promoting information technology infrastructures for the international paleomagnetic, geomagnetic and rock magnetic community.</h4></a><div class="ui secondary small pointing purple menu" style="margin: 0.25em 0px 1.25em;"><a class="item" href="/MagIC" style="padding: 0.5em 1em;">Home</a><a class="item" href="/MagIC/about" style="padding: 0.5em 1em;">About</a><a class="item" href="/MagIC/technology" style="padding: 0.5em 1em;">Technology</a><a class="item" href="/MagIC/grand-challenges" style="padding: 0.5em 1em;">Grand Challenges</a><a class="item" href="/MagIC/workshops" style="padding: 0.5em 1em;">Workshops</a><a class="item" href="/MagIC/links" style="padding: 0.5em 1em;">Links</a><div class="right menu"><a class="item" href="https://github.com/earthref/MagIC/issues" target="_blank" style="padding: 0.5em 1em;"><i aria-hidden="true" class="exclamation triangle icon"></i>Report an Issue on GitHub</a><a class="item" href="/MagIC/help" style="padding: 0.5em 1em;"><i aria-hidden="true" class="question icon"></i>Help</a><a class="item" href="/MagIC/contact" style="padding: 0.5em 1em;"><i aria-hidden="true" class="mail icon"></i>Contact</a></div></div><div class="magic-search"><div class="ui top attached tabular menu level-tabs"><div class="active item" style="background-color: rgb(240, 240, 240);">Contributions<div class="ui circular small basic label" style="color: rgb(12, 12, 12); margin: -1em -1em -1em 0.5em; min-width: 4em;"><span es="[object Object]">1 </span></div></div><div class="item" style="cursor: pointer; color: rgb(121, 47, 145);">Locations<div class="ui circular small basic label" style="color: rgb(12, 12, 12); margin: -1em -1em -1em 0.5em; min-width: 4em;"><span es="[object Object]">1 </span></div></div><div class="item" style="cursor: pointer; color: rgb(121, 47, 145);">Sites<div class="ui circular small basic label" style="color: rgb(12, 12, 12); margin: -1em -1em -1em 0.5em; min-width: 4em;"><span es="[object Object]">1 </span></div></div><div class="item" style="cursor: pointer; color: rgb(121, 47, 145);">Samples<div class="ui circular small basic label" style="color: rgb(12, 12, 12); margin: -1em -1em -1em 0.5em; min-width: 4em;"><span es="[object Object]">66 </span></div></div><div class="item" style="cursor: pointer; color: rgb(121, 47, 145);">Specimens<div class="ui circular small basic label" style="color: rgb(12, 12, 12); margin: -1em -1em -1em 0.5em; min-width: 4em;"><span es="[object Object]">66 </span></div></div><div class="item" style="cursor: pointer; color: rgb(121, 47, 145);">Experiments<div class="ui circular small basic label" style="color: rgb(12, 12, 12); margin: -1em -1em -1em 0.5em; min-width: 4em;"><span es="[object Object]">66 </span></div></div><div class="item" style="cursor: pointer; color: rgb(121, 47, 145);">Measurements<div class="ui circular small basic label" style="color: rgb(12, 12, 12); margin: -1em -1em -1em 0.5em; min-width: 4em;"><span es="[object Object]">795 </span></div></div></div><div class="ui bottom attached secondary segment" style="padding: 0px;"><div style="display: flex; width: 100%;"><div class="ui labeled fluid action input" style="padding: 1em 1em 0px; flex: 1 1 0%;"><div class="purple ui label"><i class="search icon"></i>Search MagIC</div><input class="prompt" type="text" placeholder="e.g. metamorphic &quot;field intensity&quot; -precambrian" value="id:&quot;17099&quot; " style="border-top-color: rgb(136, 136, 136); border-right: none; border-bottom-color: rgb(136, 136, 136); border-left: none; flex: 1 1 0%;"><div class="ui basic black button"><i class="search icon"></i>Search</div><div class="ui basic black button" style="margin-left: -1px;"><i class="remove circle icon"></i>Clear</div></div><div class="purple ui basic button" style="margin: 1em 1em 0px 0px;"><i class ...

# %% [markdown]
# The extracted JSON-LD

# %%
print(json.dumps(jsonld, indent=2))
# Out:
# [
#   {
#     "@context": {
#       "@vocab": "https://schema.org/",
#       "geosci-time": "http://schema.geoschemas.org/contexts/temporal#"
#     },
#     "@type": "Dataset",
#     "identifier": "http://dx.doi.org/10.7288/V4/MAGIC/{cid}",
#     "url": "https://earthref.org/MagIC/{cid}",
#     "isAccessibleForFree": true,
#     "license": "https://creativecommons.org/licenses/by/4.0/",
#     "provider": {
#       "@id": "https://earthref.org/MagIC",
#       "type": "Organization",
#       "legalName": "Magnetics Information Consortium (MagIC) Data Repository",
#       "name": "MagIC",
#       "url": "https://earthref.org/MagIC"
#     },
#     "publisher": {
#       "@id": "https//earthref.org/MagIC"
#     },
#     "sdPublisher": "EarthRef.org",
#     "sdLicense": "https://creativecommons.org/licenses/by/4.0/",
#     "sdDatePublished": "2021-03-02T16:31:57.278Z",
#     "labNames": "Paleomagnetic Lab (Helmholtz Centre Potsdam, Germany)",
#     "distribution": {
#       "@type": "DataDownload",
#       "contentUrl": "https://earthref.org/MagIC/download/{cid}/magic_contribution_{cid}.txt",
#       "encodingFormat": [
#         "text/plain; application=earthref-tsv",
#         "EarthRef-tsv-Multipart"
#       ]
#     },
#     "version": 2,
#     "contributor": "Niels Meijer",
#     "dateModified": "2021-02-24T08:04:30.134Z",
#     "citation": "<b>Niels Meijer, Guillaume Dupont\u2010Nivet, Natasha Barbolini, Amber Woutersen, Alexander Rohrmann, Yang Zhang, Xiang\u2010Jun Liu, Alexis Licht, Hemmo A. Abels, Carina Hoorn, Rik Tjallingii, Christoff Andermann, Michael Dietze, Norbert Nowaczyk (2021).</b> Loess\u2010like dust appearance at 40 Ma in central China. <i>Paleoceanography and Paleoclimatology. doi:<a href='//dx.doi.org/10.1029/2020PA003993'>10.1029/2020PA003993</a>.</i>",
#     "sameAs": [
#       "https://doi.org/10.1029/2020PA003993"
#     ],
#     "name": "<b>Niels Meijer, Guillaume Dupont\u2010Nivet, Natasha Barbolini, Amber Woutersen, Alexander Rohrmann, Yang Zhang, Xiang\u2010Jun Liu, Alexis Licht, Hemmo A. Abels, Carina Hoorn, Rik Tjallingii, Christoff Andermann, Michael Dietze, Norbert Nowaczyk (2021).</b> Loess\u2010like dust appearance at 40 Ma in central China. <i>Paleoceanography and Paleoclimatology. doi:<a href='//dx.doi.org/10.1029/2020PA003993'>10.1029/2020PA003993</a>.</i> (Dataset)",
#     "description": "Paleomagnetic, rock magnetic, or geomagnetic data found in the MagIC data repository from a paper titled: <b>Niels Meijer, Guillaume Dupont\u2010Nivet, Natasha Barbolini, Amber Woutersen, Alexander Rohrmann, Yang Zhang, Xiang\u2010Jun Liu, Alexis Licht, Hemmo A. Abels, Carina Hoorn, Rik Tjallingii, Christoff Andermann, Michael Dietze, Norbert Nowaczyk (2021).</b> Loess\u2010like dust appearance at 40 Ma in central China. <i>Paleoceanography and Paleoclimatology. doi:<a href='//dx.doi.org/10.1029/2020PA003993'>10.1029/2020PA003993</a>.</i>",
#     "datePublished": "2021-02-24T08:04:30.134Z",
#     "spatialCoverage": {
#       "@type": "Place",
#       "geo": [
#         {
#           "@type": "GeoShape",
#           "box": "36.52 102.105 36.51 102.1"
#         },
#         {
#           "@type": "GeoCoordinates",
#           "latitude": 36.5183,
#           "longitude": 102.104
#         }
#       ]
#     },
#     "temporalCoverage": {
#       "@type": "DateTime",
#       "startDate": -33998051,
#       "endDate": -52998051
#     },
#     "geosci-time": {
#       "@type": "time:Instant",
#       "time:inTimePosition": {
#         "@type": "time:ProperInterval",
#         "time:hasBeginning": {
#           "time:hasTRS": {
#             "@id": "geosci-time:BeforePresent"
#           },
#           "time:numericPosition": {
#             "@value": 34000000,
#             "@type": "xsd:decimal"
#           }
#         },
#         "time:hasEnd": {
#           "time:hasTRS": {
#             "@id": "geosci-time:BeforePresent"
#           },
#           "time:numericPosition": {
#             "@value": 53000000,
#             "@type": "xsd:decimal"
#           }
#         }
#       }
#     },
#     "variableMeasured": [
#       {
#         "@type": "PropertyValue",
#         "name": "Specimen X Direction Azimuth",
#         "description": "Azimuth of specimens\u2019s x direction measured clockwise from north",
#         "minValue": 18,
#         "maxValue": 350,
#         "unitText": "Degrees"
#       },
#       {
#         "@type": "PropertyValue",
#         "name": "Specimen X Direction Dip",
#         "description": "Dip of specimens\u2019s x direction from the horizontal increasing downward",
#         "minValue": -108,
#         "maxValue": -30,
#         "unitText": "Degrees"
#       },
#       {
#         "@type": "PropertyValue",
#         "name": "Lab Treatment DC Field",
#         "description": "Applied DC field",
#         "minValue": 0,
#         "maxValue": 0,
#         "unitText": "T"
#       },
#       {
#         "@type": "PropertyValue",
#         "name": "Bedding Dip Direction",
#         "description": "Direction of the dip of a paleo-horizontal plane of bedding (strike + 90 degrees)",
#         "minValue": 0,
#         "maxValue": 90,
#         "unitText": "Degrees"
#       },
#       {
#         "@type": "PropertyValue",
#         "name": "Latitude",
#         "description": "Sample geographic location, Latitude",
#         "minValue": 36.5183,
#         "maxValue": 36.5183,
#         "unitText": "Degrees"
#       },
#       {
#         "@type": "PropertyValue",
#         "name": "Stratigraphic Height",
#         "description": "Sample geographic location, Stratigraphic height",
#         "minValue": 6.1,
#         "maxValue": 61.3,
#         "unitText": "m"
#       },
#       {
#         "@type": "PropertyValue",
#         "name": "Inclination",
#         "description": "Directions in specimen coordinates, Inclination",
#         "minValue": -86.4255,
#         "maxValue": 87.1356,
#         "unitText": "Degrees"
#       },
#       {
#         "@type": "PropertyValue",
#         "name": "Lab Treatment Orientation Theta",
#         "description": "Orientation of the lab field with respect to the specimen during treatment",
#         "minValue": 0,
#         "maxValue": 0,
#         "unitText": "Degrees"
#       },
#       {
#         "@type": "PropertyValue",
#         "name": "Lab Treatment AC Field",
#         "description": "Peak field in AC demagnetization experiment",
#         "minValue": 0,
#         "maxValue": 0,
#         "unitText": "T"
#       },
#       {
#         "@type": "PropertyValue",
#         "name": "Volume",
#         "description": "Specimen volume",
#         "minValue": 1e-05,
#         "maxValue": 1e-05,
#         "unitText": "m^3"
#       },
#       {
#         "@type": "PropertyValue",
#         "name": "Magnetization Volume",
#         "description": "Measured intensity of magnetization, Volume normalized",
#         "minValue": 3.365752e-05,
#         "maxValue": 0.009622669,
#         "unitText": "A/m"
#       },
#       {
#         "@type": "PropertyValue",
#         "name": "Longitude",
#         "description": "Sample geographic location, Longitude",
#         "minValue": 102.104,
#         "maxValue": 102.104,
#         "unitText": "Degrees"
#       },
#       {
#         "@type": "PropertyValue",
#         "name": "Measurement Temperature",
#         "description": "Temperature",
#         "minValue": 293,
#         "maxValue": 293,
#         "unitText": "K"
#       },
#       {
#         "@type": "PropertyValue",
#         "name": "Circular Standard Deviation",
#         "description": "Circular standard deviation in measurements",
#         "minValue": 0.1,
#         "maxValue": 0.1,
#         "unitText": "Degrees"
#       },
#       {
#         "@type": "PropertyValue",
#         "name": "Creation Timestamp",
#         "description": "UTC Date and time of when image was taken or created",
#         "minValue": 1546300800000,
#         "maxValue": 1546300800000
#       },
#       {
#         "@type": "PropertyValue",
#         "name": "Declination",
#         "description": "Directions in specimen coordinates, Declination",
#         "minValue": 1.12987,
#         "maxValue": 359.703,
#         "unitText": "Degrees"
#       },
#       {
#         "@type": "PropertyValue",
#         "name": "Lab Treatment Orientation Phi",
#         "description": "Orientation of the lab field with respect to the specimen during treatment",
#         "minValue": 0,
#         "maxValue": 0,
#         "unitText": "Degrees"
#       },
#       {
#         "@type": "PropertyValue",
#         "name": "Geographic Precision",
#         "description": "Site geographic location, Precision in latitude and longitude",
#         "minValue": 0.0001,
#         "maxValue": 0.0001,
#         "unitText": "Degrees"
#       },
#       {
#         "@type": "PropertyValue",
#         "name": "Bedding Dip",
#         "description": "Dip of the bedding as measured in the bed dip direction (dip right of strike)",
#         "minValue": 0,
#         "maxValue": 0,
#         "unitText": "Degrees"
#       },
#       {
#         "@type": "PropertyValue",
#         "name": "Lab Treatment Temperature",
#         "description": "Demagnetization temperature",
#         "minValue": 393,
#         "maxValue": 923,
#         "unitText": "K"
#       },
#       {
#         "@type": "PropertyValue",
#         "name": "Lab Treatment Step Index",
#         "description": "An integer that increases by one for each measurement done during an experiment",
#         "minValue": 1,
#         "maxValue": 13
#       },
#       {
#         "@type": "PropertyValue",
#         "name": "Magnetic Moment",
#         "description": "Measured magnetic moment",
#         "minValue": 3.365752e-10,
#         "maxValue": 9.622669e-08,
#         "unitText": "Am^2"
#       }
#     ]
#   }
# ]
